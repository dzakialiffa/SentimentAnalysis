# %% [markdown]
# # Mount Google Drive dan Menginstal Library

# %%
#mounting google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install Textblob
# Out:
# Requirement already satisfied: Textblob in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.10/dist-packages (from Textblob) (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->Textblob) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->Textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->Textblob) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->Textblob) (4.66.4)

# %%
from textblob import TextBlob

# %%
import pandas as pd

# %% [markdown]
# # Memuat dan Menerjemahkan Data

# %%
data_path = '/content/drive/MyDrive/DataFix/SastrawiProssedSeabank.csv'

# %%
# !pip3 install googletrans==3.1.0a0
# Out:
# Collecting googletrans==3.1.0a0
#   Downloading googletrans-3.1.0a0.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Collecting httpx==0.13.3 (from googletrans==3.1.0a0)
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2024.6.2)
# Collecting hstspreload (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading hstspreload-2024.6.1-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 18.5 MB/s eta 0:00:00
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (1.3.1)
# Collecting chardet==3.* (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 8.5 MB/s eta 0:00:00
# Collecting idna==2.* (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.0 MB/s eta 0:00:00
# Collecting rfc3986<2,>=1.3 (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting httpcore==0.9.* (from httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 5.2 MB/s eta 0:00:00
# Collecting h11<0.10,>=0.8 (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 3.9 MB/s eta 0:00:00
# Collecting h2==3.* (from httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 5.2 MB/s eta 0:00:00
# Collecting hyperframe<6,>=5.2.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Collecting hpack<4,>=3.0 (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==3.1.0a0)
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-3.1.0a0-py3-none-any.whl size=16353 sha256=63a2bf32f7a0bf482b225281aca1abb0eaf3452ceafc42ead329202d24e2ffe9
#   Stored in directory: /root/.cache/pip/wheels/50/5d/3c/8477d0af4ca2b8b1308812c09f1930863caeebc762fe265a95
# Successfully built googletrans
# Installing collected packages: rfc3986, hyperframe, hpack, h11, chardet, idna, hstspreload, h2, httpcore, httpx, googletrans
#   Attempting uninstall: chardet
#     Found existing installation: chardet 5.2.0
#     Uninstalling chardet-5.2.0:
#       Successfully uninstalled chardet-5.2.0
#   Attempting uninstall: idna
#     Found existing installation: idna 3.7
#     Uninstalling idna-3.7:
#       Successfully uninstalled idna-3.7
# Successfully installed chardet-3.0.4 googletrans-3.1.0a0 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2024.6.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 idna-2.10 rfc3986-1.5.0

# %%
# Importing library yang dibutuhkan
import googletrans
from googletrans import Translator

# %%
data = pd.read_csv(data_path)
data.head()
# Out:
#                                              content
# 0                                                NaN
# 1                                                top
# 2           aplikasi ak penyandang disabilitas netra
# 3                                             mantap
# 4  terbaik kepuasan ya pengguna nyaselain manfaat...

# %%
translator = Translator()
translations = {}
for column in data.columns:
    # Unique elements of the column
    unique_elements = data[column].unique()
    for element in unique_elements:
        # Adding all the translations to a dictionary (translations)
        translations[element] = translator.translate(element).text
translations
# Out:
# {nan: 'in',
#  'top': 'top',
#  'aplikasi ak penyandang disabilitas netra': 'application for children with visual disabilities',
#  'mantap': 'solid',
#  'terbaik kepuasan ya pengguna nyaselain manfaat dapatkan bertransaksi aplikasi bagus ya memiliki manfaat mudah membeli pulsa membayar tagihan listrikpdam dll aplikasi nya membantu ya berkat aplikasi kemudahan fitur fitur dimiliki aplikasi kawan': "The best user satisfaction, apart from the benefits of getting transactions, the application is good, yes it has the benefit of easily buying credit, paying electricity bills, water supply, etc. the application is helpful, thanks to the application's ease of features, friends' application.",
#  'suka buka rekening trasfer lancar kendala pembaharuan kasih membingungkan pokoknya bagus de semoga maju sukses': "I like opening a transfer account smoothly, but the problem with renewal is confusing, but it's good, good luck moving forward",
#  'senang kalo saldonya bnyak': "I'm happy if I have a lot of balance",
#  'toppppp': 'toppppp',
#  'membantu': 'help',
#  'cepat mudah': 'fast easy',
#  'goks': 'gok',
#  'pokoknya joss': 'basically joss',
#  'suka': 'criticism',
#  'baguss': 'nice',
#  'praktis dn transfer free biaya admin semoga kedepannya terima kasih': 'Practical and transfers are free of admin fees. Hopefully in the future, thank you',
#  'bagus membantu tranfer berguna semoga berkembang': 'good help, useful transfer, hopefully it will develop',
#  'bfua': 'bfua',
#  'sempurna banget ya alat transfer kesesama bank digital yamenurut aplikasi bagus ya tinggal ditambah menu pelengkap biar sempurna utc memudahkan aplikasi nya jaringan stabil prose transaksi cepat menjadikan aplikasi aplikasi nyaaplikasi pa transaksi ya': "It's really perfect, a transfer tool between digital banks, according to the application, it's good, just add a complementary menu to make it perfect. UTC makes the application easy, the network is stable, the transaction process is fast, making the application a good transaction application, OK?",
#  'oke bangeeet': 'okay really',
#  'oke': 'limit',
#  'tambahkan fitur konfirmasi pembayaran finger print pin ribet ketik pin konfirmasi pembayaran transfer': "add the finger print pin payment confirmation feature. It's complicated to type the transfer payment confirmation pin",
#  'asyikk': 'asyikk',
#  'bagus': 'Good',
#  'good': 'good',
#  'bintang yg bicara': 'talking star',
#  'penggunaan mudah bermanfaat bebas biaya tf': 'easy to use, useful, free of charge tf',
#  'okeee': 'okay',
#  'mudah murah': 'easy cheap',
#  'transfer e wallet bank pake gratisseabank top': 'Bank e-wallet transfer using Seabank Top for free',
#  'keren': 'keren',
#  'puas penggunaan nya': 'satisfied with its use',
#  'asik mantap': 'cool cool',
#  'perbaiki amanan nya': 'improve security',
#  'jempol': 'thumb',
#  'kemudahan aplikasi ponsel ya aplikasi nya bermanfaat kepuasan yafitur fitur nya lengkap memudahkan penggunaanyaapllikasi nya lancar ya kepuasan bertransaksi disinimenurut aplikasi bagus sempurna banget ya tinggal ditambah menu pelengkap utc memudahkan aplikasi nya jaringan jlk': "the convenience of the cellphone application, yes, the application is useful, satisfaction, the features are complete, it makes it easy to use, the application is smooth, yes, the satisfaction of making transactions here, according to the application, it's really perfect, yes, just add a complementary menu, UTC makes the application easier, jlk network",
#  'untung akun ovo hack terima kasih': 'Luckily the OVO account was hacked, thank you',
#  'akongz bagus transaksi nya gratis': 'akongz is good, the transactions are free',
#  'cepet pelayanan': 'fast service',
#  'serba mudahhanya rumah': 'everything is easy, just the house',
#  'kemudahan bertransakti bunga cair': 'ease of transacting liquid interest',
#  'coba': 'try',
#  'aplikasi nya bagus banget yasimpel mudah pastinya kemudahan pengguna nyaselain manfaat dapatkan mudah membeli pulsabayar tagihan listrik manfaat aplikasi bagus nya aplikasi nya dilengkapi fitur fitur lengkap memudahkan aplikasi nya bertransaksi ya kawan': "the application is really good, it's simple, easy, of course it's easy for users, apart from the benefits of getting it, it's easy to buy credit, pay electricity bills, the benefits of the application are good, the application is equipped with complete features, the application makes transactions easy, friends",
#  'bantuan admin laporin transaksi palsu akun kena blokir mbanking ga': 'Admin help report fake transactions, your account has been blocked by mbanking or not',
#  'yaaa': 'yeah',
#  'nyaman': 'comfortable',
#  'prose cepat': 'fast process',
#  'prose nya cepat': 'the process is fast',
#  'okelah': 'Okay',
#  'bermanfaatapky enak gak ribet': 'useful, delicious, not complicated',
#  'membantu ya semoga kedepan kendala': 'It helps, hopefully there will be problems in the future',
#  'bank digital termudah': 'Easiest digital bank',
#  'bagus kenyamanan transaksi didalamnya salah satunya salah aplikasi terbaik dikelasnya bagus detail komponen yg terkandung didalamnya pemakaian amanah terpercaya sia sia udah menabung suku bunga tambahan fitur terbaru yg keren update mantap frendddd': "good transaction convenience in it, one of the best applications in its class, good details of the components contained in it, use of trusted trusts, it's useless to save, additional interest rates, cool new features, great updates, frendddd",
#  'good aplikasion': 'good application',
#  'bagus banget': 'really good',
#  'pake bintang ya': 'Use stars',
#  'happy': 'happy',
#  'bebas admin transaksi': 'admin free transactions',
#  'nice': 'nice',
#  'kecewa aplikasi seabanksaya login kluar trus login tertulis nik digunakansaya login modelnya kaya disuruh daftarsekali bilang login mw daftar': 'Disappointed with the Seabank application, I logged in, it exited, then login said Nik was used. I logged in, the model was like I was told to register, once it said login, I registered.',
#  'transaksi simpel': 'simple transaction',
#  'senang': 'like',
#  'cakepp tf': 'cakepp tf',
#  'praktis hemat biaya': 'practically cost-effective',
#  'aplikasi yg membantu bermanfaat pembisnis yg pembelian barang via transfer penjualan barang diseluruh indonesia ayok kembangkan aplikasi sejagat raya indonesia terima kasih': "an application that helps, useful for business people who purchase goods via transfer, sell goods throughout Indonesia, let's develop an application throughout Indonesia, thank you",
#  'joss': 'joss',
#  'buruk': 'bad',
#  'baguspelayanan cepat transfer kemanapun gratis biaya ribet pertahanan': 'good service, fast transfers anywhere, free of hassle of defense costs',
#  'menarik serbaguna makasih seebank': 'Interesting, versatile, thanks Seabank',
#  'bagus nyooo': "that's good noooo",
#  'bagus aplikasi nta': 'really good application',
#  'secepat kilat': 'lightning fast',
#  'alkhamdulillahberkah berkah berkahsemoga aplikasi mengutamakan pelanggan mengutamakan keamanan kenyamananaamiin': 'Alkhamdulillah, blessings, blessings, blessings, hopefully the application prioritizes customers, prioritizing security, comfort, amen',
#  'kekurangan nya gak tarik tunai': 'the disadvantage is that it does not withdraw cash',
#  'memudahkan transaksi': 'make transactions easier',
#  'membantu cepat': 'help fast',
#  'sistem yg': 'system which',
#  'ok': 'ok',
#  'semoga maju sukses': 'good luck moving forward',
#  'habis tf k notifikasi masuk uangnya ga masuk beranda suruh menghubungi bantuan udh jam ga jwban butuh bgt': "After TF, the notification came in, the money didn't arrive, the homepage told me to call for help, after hours, no answer, I really need it",
#  'trf shoppe wallet': 'trf shoppe wallet',
#  'mantappppp': 'cool',
#  'aplikasi tololl aplikasi gagal tolong hati² penipuan plis coba² mending menyesal kasih ulasan gaada korban lainya ok': "Tololl application failed, please be careful of fraud, please try, it's better to regret giving a review, there are no other victims, OK",
#  'memudahkan': 'facilitate',
#  'bagusss free tf kemna sja': 'Nice, free TF anywhere',
#  'membantu bermanfaat': 'helpful helpful',
#  'ui tolong ubah': 'ui please change it',
#  'bagus memuaskan memudahkan transaksi': 'good, satisfying, makes transactions easy',
#  'nyaman bnget makenya kuota gratis transfer admin': "It's really convenient because the quota is free for admin transfers",
#  'mantep': 'steady',
#  'enak gratis tf kemana aja': 'nice free tf anywhere',
#  'alhamdulillah semoga aman': "thank God, hopefully it's safe",
#  'mudah': 'easy',
#  'update ga masuk gimana sih jaringan buka aplikasi laen lancar jaya': "the update doesn't go in, how can the network open the laen application smoothly?",
#  'apk yg bermanfaat recomend': 'useful apk recommend',
#  'mencoba semoga lancar jujur terpercaya mudah menanggapi komentar pengguna': 'try to be smooth, honest, reliable, easy to respond to user comments',
#  'kerren': 'last',
#  'bagus membantu': 'good help',
#  'gimana ya daftar sulit foto muka gagal pdhl notif eror': 'How come the difficult list of face photos failed even though the notification was an error?',
#  'oke mantap': 'okay great',
#  'okehhh bangetttt senang pake': 'okay, really happy to use it',
#  'bagus sea bank gratis transfer bank lokas gratis transfer e walletehskrg udh aja kayak bank laintf beda bank e wallet udh kena cassama aja dgn bank lainkalau kembalikan kebijakan nya kayak gratis bank e wallet': "good sea bank free local bank transfers free e wallet transfers now it's just like other banks but different e wallet banks just have to be cassed with other banks if you return the policy is like free bank e wallet",
#  'manttapp bgt da playanan nya smga sukses slalu senang pke playanan nya jg ramah': 'The service is really great and good luck. Always happy with the friendly service',
#  'csnya ramah': 'CS is friendly',
#  'seruuu gatau berasa seneng aja terhubung sm shopee': "I'm so excited to be connected to shopee sm",
#  'mudah banget pengoperasiannya': 'very easy to operate',
#  'enak banget': 'very tasty',
#  'pokoknya terbaik': 'basically the best',
#  'suka aplikasi nya yg ngegunainnya kaya bingung kalo naro duit d apk nya tbtb tarik tarik tunai ny dimana kdng d pindahan dlu rekening d tarik': "I like the application that uses it, I'm confused if I want money in the apk, I can't pull it, pull it, cash it, where it's transferred to the account, pull it",
#  'cepat': 'fast',
#  'membantumenggunakan nya jg mudahstiap transaksi nya gratis pulasangat puas': "It helps to use it easily, every transaction is free and I'm very satisfied",
#  'lancar mudah transaksi ya berkat aplikasi iniselain memiliki fiturfitur komplit aplikasi canggih ya memudahkan transaksi ya kawandimasa membutuhkan aplikasi membantu aplikasi iniluar kepuasan kemudahan pengguna nyapas banget transaksi ponsel': "smooth, easy transactions, thanks to this application, apart from having complete features, a sophisticated application, it makes transactions easy, friends, when you need an application, this application is beyond satisfaction, the user's ease really makes cellphone transactions easy",
#  'gak login periksa koneksi internet normal internet': 'not logged in, check the internet connection is normal',
#  'pengguna bagus paten paten x': 'good user patent patent x',
#  'buka rekening dah berminggu ga selesai nunggu notif': "Opened an account, I haven't finished waiting for a notification for weeks",
#  'jelek narik saldo aplikasi eror sistem sibuk butuh uangnya': 'Badly withdrawing balance, application error, system busy, need the money',
#  'mudah penggunaannya ga pake ribet': 'easy to use without any hassle',
#  'memuaskan': 'satisfying',
#  'good jobb': 'good',
#  'ribet worth it karna biaya admin love bgt flipp': 'the hassle is worth it because of the admin fees, really love Flipp',
#  'mantull': 'mantull',
#  'aplikasi bagus mengatur pengeluaran memiliki fitur pengelolaan keuangan membantu menabung praktis dibandingkan mendaftar bank digital coba rekomended transaksi aplikasi nyaman cepat alhamdulilah kendala transaksi update tambahkan fitur pengguna bosan aplikasi': 'good application for managing expenses, has financial management features, helps save, practical compared to registering with a digital bank, try recommended application transactions, convenient, fast, thank God, transaction problems, updates add features, users are bored with the application',
#  'suka banget transfer pake mantab': 'really like the transfer using Mantab',
#  'mantap transaksi nyatapi sayangkan voucernya rb': 'great transaction, but unfortunately the voucher is Rp',
#  'menyenangkan transaksi': 'pleasant transaction',
#  'alhamdulillah coba terbaiksmoga': 'Thank God, try your best, hopefully',
#  'gampang cepat gratis': 'easy fast free',
#  'puas': 'damage',
#  'mntp daptar': 'mintp list',
#  'lmyn kirim rek free biaya nya semoga berlanjut': 'lmyn send a free account, hopefully it will continue',
#  'the best': 'the best',
#  'bermanfaat': 'beneficial',
#  'transaksi nya cepat aman': 'the transaction is fast and safe',
#  'lancar': 'fluent',
#  'transaksi shopee bayar pakai pesanan bayar saldo terpotong statusnya terbayar batalin saldo refund komplain suruh tunggu kejelasan saldo terpotong': 'Shopee transactions pay using orders, pay the balance deducted, the status is paid, cancel the balance, refund, complaint, order to wait for clarity on the balance deducted',
#  'top up kaspro tanggal sampe sekrng terkirim duit nya padhal riwayat aplikasi udah sukses coba top up aplikasi eh ngga tunggu detik udah nambah saldo kaspro nya sanggat kecewa ama ni aplikasi': "top up kaspro date until as soon as the money is sent, the history of the application has been successful, try to top up the application, don't wait for the moment to increase the kaspro balance, I am very disappointed with this application",
#  'terima kasih merespon penangannya': 'thank you for responding to the handler',
#  'perfect': 'perfect',
#  'nomor aktp susah login disuruh ngehubungi no aktp aneh': 'Aktp number is difficult to log in, told to call strange Aktp number',
#  'sea bank oke bgt': 'Sea Bank is really good',
#  'diakui aplikasi memiliki manfaat ya nyaman bertransaksi kawanaplikasi nya ringan ngga ribet penggunaan nyamenurut aplikasi bagus ya tinggal ditambah menu pelengkap biar sempurna utc memudahkan aplikasi nya jaringan stabil yafitur fitur nya lengkap komplit ya': "It is recognized that the application has benefits, yes, it's comfortable to make transactions, friends, the application is light, it's not complicated to use, according to the application, it's good, just add a complementary menu to make it perfect, UTC makes the application easier, the network is stable, yes, the features are complete, yes.",
#  'mudah semoga aman': 'easy, hopefully safe',
#  'biaya admin murah': 'cheap admin fees',
#  'mantap transaksi dikenakan biaya': 'However, transactions are subject to fees',
#  'membantu transaksi': 'assist with transactions',
#  'mantaaab sea bank': 'Mantalab C Bank',
#  'bagus apk praktis': 'nice practical apk',
#  'memuaskankarena transfer bank biaya tambahan': 'satisfactory because bank transfers are additional fees',
#  'alhamdulillah sdh pakai': 'Thank God I have used it',
#  'mantap berkualitas mumpuni': 'solid, good quality',
#  'membantu terimakasih': 'help thank you',
#  'c cuancuan n cuan': 'c how much n how',
#  'snagat nyaman': 'very comfortable',
#  'is the best': 'is the best',
#  'mudah gampang transfer kemana aja gratis biaya kirim bagus sih': 'easy, easy transfer anywhere, free shipping, great',
#  'mudah nyaman terpercaya': 'easy comfortable reliable',
#  'set': 'set',
#  'layanan sangatt': 'very good service',
#  'sangan membantu': 'very helpful',
#  'bermanfaat trimaksih': 'useful thanks',
#  'sibang deposito palas': 'sibang palas deposit',
#  'mudah membantu': 'easy to help',
#  'ok siip': 'OK, great',
#  'prose cepat amanah': 'Fast and reliable process',
#  'serba cepat pokoknya the best': 'Fast is the best',
#  'goodlah': 'goodlah',
#  'ok d bgus': 'ok d bgus',
#  'bagus banget investasi': 'really good investment',
#  'mantap dah pokonya': "It's good, that's all",
#  'mantap bagus': 'great, good',
#  'love': 'love',
#  'bagus berkualitas': 'good quality',
#  'membantu apapun pendapat bunga ya membantu': 'Help, whatever your opinion is, yes it helps',
#  'transfernya cepat': 'the transfer is fast',
#  'aplikasi e bank termantao mantapppp transfer rekening ovo gratissss x': 'The most reliable e-bank application for free OVO account transfers x',
#  'good job': 'good job',
#  'efesien transfer gratis': 'efficient free transfer',
#  'membantu bagus banget pelayanannya kalo kartu debit flazz nya bagus sih': 'the service is really good if the flazz debit card is good',
#  'mudah gk ribet': 'easy, not complicated',
#  'suka menabung sea bank tranfer gratis admin': 'like saving seabank free transfer admin',
#  'goodluck': 'goodluck',
#  'maju trus': 'move on then',
#  'memuaskan terimakasih': 'satisfying thank you',
#  'sagat puas': 'very satisfied',
#  'semoga maju tingkatkan ya kinerja nyatq': 'Hopefully progress will increase real work power',
#  'mudah nyaman berbunga gak lumayan': 'easy comfortable flowering not bad',
#  'mudah cepat dg bi fast free biaya transfer': 'easy fast and bi fast free transfer fees',
#  'gimana sih saldo nerima transaksi pengirim berhasil saldo tetep kosong gimana terusan saldo yg transfer blum masuk': 'How does the balance receive a successful delivery transaction? The balance remains empty. How is the transfer balance not yet received?',
#  'terbaik': 'the best',
#  'aplikasinya bagus mudah': 'the application is good and easy',
#  'transaksi cepat cuman utk pinjaman msh blm': 'Fast transactions, only for loans yet',
#  'membantu kebutuhan financial': 'help with financial needs',
#  'mantaaap mudah': 'really easy',
#  'bank digital serba belanja shopee transfer gratis bunga ga biaya admin bulanan bagus bgtlah': 'All-in-one digital bank for shopee shopping, interest free transfers, no monthly admin fees, really good',
#  'free biaya transfer all rek kuotabulan': 'Free transfer fees for all monthly quota accounts',
#  'mempermudahkan': 'simplify',
#  'bagus semoga sukses': 'good, good luck',
#  'lumayan baguss apk nya membantu transaksi ewalet bank': 'The apk is pretty good for helping bank e-wallet transactions',
#  'sat set gak ribet bunganya gede suka': 'the set is not complicated, the flowers are big, I like it',
#  'bank terbaik yg': 'the best bank',
#  'gratis tf nyaa banyakk membantu': 'The free TF helps a lot',
#  'opsional': 'optional',
#  'mudah penggunaannya membantu': 'ease of use helps',
#  'setia transfer uangalasan nyakarena aplikasi nya update promo terbaru terkiniisi fitur nya lengkap bagus keamanan nya terpercayakalau cuman membosankan aplikasi menghasilkan uang ajak teman kelebihan aplikasi inisecara aplikasi nya rekomendasi banget kawankawan': "loyal to transfer money, the reason is because the application is updated with the latest promos, the features are complete, good, the security is reliable, if it's just boring, the application makes money, invite friends. The advantages of this application are that the application is really recommended, friends.",
#  'mudah ktimbang dana msh bingung krna pemula': "It's easy to compare funds but you're still confused because you're a beginner",
#  'mantab guy': 'mantab guy',
#  'gratis smua bank thx': 'free for all banks thx',
#  'sukaaak bangeeet gratis admin gratis biaya transfer kemanapun semoga yaa amiiin': 'really like it, free admin, free transfer fees anywhere, hopefully, amen',
#  'min gak adain fitur cetak langsung ukuran kertas lebar mm memudahkan cetak bukti transfer': 'Min, there is no direct print feature, the paper size is mm wide, making it easier to print transfer proof',
#  'wow amazing': 'wow amazing',
#  'bagus gakribet': 'good, not complicated',
#  'mudah terbaik': 'easy best',
#  'mudah cepat murah': 'easy fast cheap',
#  'krm mami': 'thanks to mom',
#  'nyaman mudah senang seebank': 'comfortable easy happy seabank',
#  'mengalami kadaluarsa nomor hp login disuruh input kode otp mengubungi c dihubungi ya': 'If your cell phone number has expired, you are asked to enter the OTP code. Contact C. Call me',
#  'pertahankan teruss kulaitasnya bikin user kecewa mantap': 'Continuing to maintain the quality will make users really disappointed',
#  'mudah biaya gratis biaya tf': 'easy fees free tf fees',
#  'kali coba lihat kedepan nya kendala ataw gk': 'Try to see if there are any obstacles in the future or not',
#  'mantapp': 'great',
#  'segi tampilan iu nya aplikasi nya simpel mudah ya kawan aplikasi ringan enak banget dipakaiada faktor aplikasi unggul dibandingkan aplikasi ya fitur fitur nya lengkap memudahkan pengguna nya aplikasi pengalaman aplikasi bug': "In terms of appearance, the application is simple, easy, friends, the application is light, it's really nice to use, there are superior application factors compared to applications, yes, the features are complete, making it easier for users to experience the application, application bugs",
#  'senang prose sulid': "I'm glad the process is smooth",
#  'membantu mempermudah bertransaksi apapun': 'helps make any transaction easier',
#  'sih mencoba aja sih aplikasi bagus bermanfaat banget lho kawanselain fitur fitur nya lengkap kepuasan aplikasi nya bertransaksi kawanmenariknya mengundang kerabat aplikasi tambahan penghasilan lumayan lhobonus aplikasi tarik saldo dana kawan': "Just give it a try, it's a good application, it's really useful, friends, apart from the complete features, the satisfaction of the application makes transactions with friends, it's interesting to invite relatives, the additional income application is quite good, you know, the bonus application is to withdraw funds, friends",
#  'baikkk lahhhh': "it's okay",
#  'mantap klo transaksi terjamin sy udh merasakannya klo transaksi ap aja bebas admin mantap': "It's great if the transaction is guaranteed, I already feel that it's great if any transaction is admin free",
#  'urusan mudah simple berkat nya aplikasi seabankgampang mudah dipakaidiantara aplikasi sejenisnya aplikasi yg bagus puas pelayanannyadijamin mudah transaksi daftarnya syratnya gampang ktp ngga ribet yamenurut aplikasi bagus tinggal ditambah pelengkap utc memudahkan menggunakannya jaringan stabil': "easy business, simple thanks to the seabank application, easy to use, among similar applications, good application, satisfied with the service, guaranteed easy transaction, registration, easy registration, no hassle, according to the application, it's good, just add the UTC supplement, making it easy to use, stable network",
#  'maantap': 'todayp',
#  'aplikasi nya membantu banget ya memiliki manfaat besarsimpel mudah digunakanuntuk urusan transaksi aplikasi jagonyamenurut aplikasi bagus ya tinggal ditambah menu pelengkap komplit utc memudahkan aplikasi disaat jaringan stabil yaaplikasi layak apresiasi bintang kawan': 'the application is really helpful, yes, it has big benefits, simple, easy to use, for transaction matters, the application is good, according to the application it is good, just add a complete complementary menu, UTC makes the application easier when the network is stable, yes, the application deserves star appreciation, friends',
#  'layanannya mantap': 'the service is great',
#  'adakan atm aplikasi pinjaman ya': 'hold a loan application atm yes',
#  'saldo masuk akun seabankpadahal bank pengirim suksessangat mengecewakan': 'the balance entering the seabank account even though the sending bank was successful was very disappointing',
#  'lancar jaya terima kasih': 'good luck thank you',
#  'apk tepercaya insha allah slama pakai amanah aman': 'Trusted apk, God willing, always safe to use',
#  'kecewa ak ngirim saldo dana tpi saldo nya gk masuk² pdhl saldo dana berkurang gimana developer tolong perbaiki': "I'm disappointed I sent the balance of funds but the balance didn't arrive even though the balance of funds was reduced. How can the developer please fix it?",
#  'menyukai transfer gratis': 'love free transfers',
#  'mohon bantuannyakepada yg terhormat pad jm sore isi saldo jam saldo masuk rekening': 'Dear Sir, please help in the afternoon to fill in the balance when the balance enters the account',
#  'mantul aplikasi membantu mudah dipahami': 'Mantul application helps easy to understand',
#  'aplikasi kemudahan ya prose transaksi onlinesimpel mudah didownload yaselain fitur fitur dimiliki aplikasi nya lengkap banget memuaskan banget ya bertransaksi online kebanyakan orang orang diluar memilih aplikasi urusan transaksi nyadiantara bank digital aplikasi nya nya': "The application is easy, the online transaction process is simple, easy to download, apart from the features the application has, it's complete, it's really satisfying, yes, when making online transactions, most people outside choose the application for transaction affairs, including the digital bank application.",
#  'mudah dimengerti buka rekening tabungan online mudah praktis siapkan ktp langsung aplikasi aplikasi shope suka belanja cocok banget pakai aplikasi transaksi mudah cepat qris bebas biaya admin transfer bank aplikasi nyaman menabung jangka bunga deposito nya semoga bermanfaat developer': "easy to understand, open an online savings account, easy and practical, prepare your ID card directly, the Shope application, likes shopping, is really suitable for using the fast, easy transaction application, QRIS, free admin fees, bank transfers, convenient application for saving, the deposit interest term, I hope it's useful, developer",
#  'kali kejadian transferan ewallet ga masuk status berhasil ewallet berbeda c template dana masuk dana masuk skrg kapok pakai': "In the event that an ewallet transfer doesn't go through, the ewallet success status is different. The incoming funds template has now given up on using it",
#  'diskon harga mudah terimakasih': 'Easy price discount, thank you',
#  'nice app': 'nice app',
#  'usahakan tarik tunai minimarket alfamartindomaret dll kenakan biaya admin': 'try to withdraw cash from Alfamartindomaret minimarkets, etc. and charge admin fees',
#  'gajiaan haha': 'salary haha',
#  'bagusss': 'nice',
#  'enak dipake nabung': 'good for saving',
#  'mantap aman sesuai': 'steady safe suitable',
#  'mantab': 'great',
#  'mantap grts transfer': 'great, grts transfer',
#  'bagus prose ny': "that's a good process",
#  'senang banget transfer pakai bebas biaya admin daftar akunnya gak ribet ayo download aplikasi buruan download jamin nyesal': "really happy to transfer using free admin fees, register an account, it's not complicated, come on, download the application, hurry up and download it, I guarantee you won't regret it",
#  'biaya transfer bl fast bank': 'fast bank transfer fees',
#  'mudah aman bertransaksi': 'easy safe transactions',
#  'bagus mantap cepat': 'good, fast',
#  'mudah bebas admin': 'easy admin free',
#  'bagussss bangettt': 'very good',
#  'regristasi gagal': 'registration failed',
#  'mudah bertransaksi': 'easy transaction',
#  'abang': 'brother',
#  'min nanya nihpernah akun tp sy gak masuk akun lg ya': "I'm asking, I've had an account but I'm not logged into my account anymore",
#  'mantap membantu': 'really helpful',
#  'aplikasi transfer mudah gratis biaya admin tetimakasih': 'Easy transfer application, free admin fees, thank you',
#  'fungsional': 'functional',
#  'bagus bebas biaya admin': 'good, no admin fees',
#  'transaksi mudah cepat terima kasih': 'fast easy transaction thank you',
#  'mantap bermanfaat': 'really useful',
#  'lemot anj ga d pencet kesel bgt gua udah pngn gua apus aj ni aplikasi nyesel ad saldo d dlmnya d bayar g d pencet': "It's too late, I can't press it, I'm so upset, I'm sorry, I'm sorry, the application has a balance in it, I paid it, and I press it",
#  'praktis': 'practical',
#  'ok mantap': 'okay great',
#  'berguna': 'useful',
#  'kaya gini': 'rock gini',
#  'menikmati aplikasi memakai nya kejadian menyebabkan bintang top up masuk keterangan sukses saldo terpotong sdh laporan disuruh menunggu hr kerja hr perubahan kejelasan disuruh menunggu gunanya mempermainkan customer solusi hati instal aplikasi korban': "enjoy the application using it, the incident caused the top up star to enter the success statement, the balance was deducted, the report was told to wait for the working day, the clarity change date, was told to wait, the point is to play with the customer, the solution to the heart, install the victim's application",
#  'siippp aplikasi oke banget': 'siippp the application is very good',
#  'membantu teruskan ya gratis biaya adminnya': 'keep helping, free admin fees',
#  'komen bot smua': 'comment bot smua',
#  'mntap': 'mntap',
#  'membantu pemakaian mudah': 'helps easy use',
#  'betah nyaman banget ya aplikasi inisimpel efisien banget digunakanproses transfer nya cepat nyaman banget bertransaksi aplikasi ya kawan kawanmenurut aplikasi nya bagus menyenangkan aplikasi rebutan nyasejauh aplikasi nya bug ya kawan kawan': "really comfortable, this application is simple, very efficient to use, the transfer process is fast, very convenient to make transactions with the application, friends, according to the application, it's good, it's fun, the application is up for grabs, so far the application has bugs, friends, friends",
#  'niceee': 'niceee',
#  'aplikasi mantap': 'great application',
#  'transaksi pakai sea bank alhamdulilah lancar': 'Thank God, the transaction using Sea Bank was smooth',
#  'bgus': 'nice',
#  'bagus membantu mempermudah cepat intinya joss gandosss': 'nice to help make things easier quickly, the point is joss gandosss',
#  'pengalaman menulis terbaik poin bagus desain barel berwarnawarni ujung nikel perak poin': 'best writing experience good points multicolored barrel design nickel silver tip points',
#  'gratis biaya transfer prose cepat pokoknya isbthe best': 'free transfer fees, fast process, basically is the best',
#  'akun gak dibuka telpon c nya bilang data bermaslah disuruh coba x jam x jam telpon csnya tbtb c nya bilang melaporkan akun karna tagihan dilunaskan transaksi orang bank bertanggung disuruh cari si pelapor pokoknya kecewa pake': "the account wasn't opened, he called the c, he said there was a problem with the data, he was told to try x x hour, he called the cs, tbtb, the c said to report the account because the bill was paid off, the transaction, the bank person was responsible, he was told to look for the reporter, basically he was disappointed.",
#  'siip': 'cool',
#  'kerensangat terbantu transaksi cepat': 'cool, really helped with fast transactions',
#  'mantul': 'Really good',
#  'aplikasi cerdas': 'smart application',
#  'toplaaahpake biar gratis biaya penanganan co shopeeeeeh tf gratis beda bank': "Toplaaahuse it so it's free from co-shopee handling fees, free tf from different banks",
#  'mantap pertahankan tingkatkan min': 'keep it up keep improving min',
#  'mudah cepat pertahankan': 'easy and fast to maintain',
#  'jos': 'if',
#  'luv bangett apk the best kalo transfer gratis ti ti': 'luv reallyt apk the best if free transfer ti ti',
#  'gampang mengerti': 'easy to understand',
#  'gratis admin tpi klo top up rek pakai admin': 'admin is free but if you top up your account you use admin',
#  'sip ol': 'ship the',
#  'foto ktp foto muka tinggal pin susah banget keterangan pin kuat emangnya angkat berat dicoba kali keterangan': "ID card photo, face photo, just a pin, it's very difficult, the description of the pin is strong, it's really hard to lift, try the description several times",
#  'sebnk pinjam muncul': 'seabank loans appear',
#  'murah': 'cheap',
#  'simpel': 'easy',
#  'semoga amanah kedepan nyaamin': 'I hope you have trust in the future',
#  'senang transaksi gratis bunga': 'Happy interest free transaction',
#  'manfaat bgt': 'great benefits',
#  'mantap transfer biaya': 'steady transfer fees',
#  'mudah cepat pembayaran nya': 'easy and fast payment',
#  'memudahkan transfer via virtual account': 'makes it easy to transfer via virtual account',
#  'top pertahankan': 'top keep it up',
#  'bagus pertahankan': 'good keep it up',
#  'mntaps': 'mntaps',
#  'nya mudah': "it's easy",
#  'gud': 'gud',
#  'amanah ramah c nya': 'his friendly trust c',
#  'membantu mudah pengunaannya': 'help ease of use',
#  'tf gratis kemanapun aplikasi mudah membantu': 'free tf wherever application is easy to help',
#  'bagus bisnis': 'good business',
#  'kalo sempurna karna kesempurnaan milik allah swt': "If it's perfect, it's because perfection belongs to Allah SWT",
#  'hai puas banget pakai nahhh kasih masukan nih gimana pembaruan sediakan kantongkantong layanan nabung diharapkan pengguna tabungan sediakan kantong simpanan terkunci sharing nabung user tabungan qurban user diajak semoga saran terwujud ya ditunggu updatenya': 'hi, really satisfied with using it, give me your input, how is the update? provide savings service pockets, savings users are expected to provide a locked savings pocket, share savings, savings users, sacrificial savings, users are invited, hopefully the suggestions come true, wait for the update',
#  'membantu trima kasih': 'help thank you',
#  'ya nya pake': 'of disposable',
#  'mantaf': 'great',
#  'mantap coba kasih pinjamanakan mantap uang masuk palang jt jt': 'great, try giving a loan, it will be great, the money will come in at least a million million',
#  'cakep': 'handsome',
#  'sempurna': 'perfect',
#  'berkat aplikasi memudahkan transaksi ya mudah simpel didukung fitur fitur lengkap komplit memudahkan transaksi ya kawan kawanmenurut aplikasi nya cocok super sibuk membantu melancarkan urusan transaksi mengirim cuanmembeli pulsa manfaat dapatkan ya': "Thanks to the application, it makes transactions easy, it's easy, it's simple, it's supported by complete features, it makes transactions easy, friends, according to the application, it's suitable, it's super busy, it helps smooth out transactions, send money, buy credit, get benefits, okay?",
#  'bagusnya aplikasi bagus tiada tara kalinya menemukan aplikasi transaksi ringan aman simple aplikasi terfavorit yg ponselku mudah dipahami fitur menunya fitur transfer uang yg amanah terpercaya transaksi hasilnya sesuai layak bintang fulll': 'the good application is incomparable, I found a light transaction application, safe, simple, the most favorite application on my cellphone, easy to understand, menu features, money transfer feature, trustworthy, reliable, transaction results are worthy of full stars',
#  'suka biaya transfer grtisan manapun kereeenn': 'I like any free transfer fee which is cool',
#  'mantap sea bank': 'great sea bank',
#  'mantap prose mudah cepat terpercaya terima kasih sea bank': 'Great process, easy, fast, reliable, thank you, Sea Bank',
#  'mudahcepat bahagia': 'easy to be happy',
#  'log out terussaat transaksi nya cepat': 'Always log out when transactions are fast',
#  'manfaat dapatkan aplikasi ya simpel sederhana banget kawanselama aplikasi bug yafitur fiturnnya lengkap memudahkan nya aplikasi ditambah utc aplikasi nya sempurna membantu banget jaringan stabil ya kawan': 'the benefits of getting the application are simple, very simple, friends, as long as the application has bugs, the features are complete, making the application easy, plus UTC, the application is perfect, the network is really stable, friends',
#  'aplikasi bagus': 'good app',
#  'aplikasi rekomendasi kendala': 'obstacle recommendation application',
#  'tingkatkan pelayanan': 'improve service',
#  'mudah praktis suka': 'easy, practical, like it',
#  'nyaman pokoknya pertahankan': 'comfortable, just keep it up',
#  'cocok shopee user': 'suitable for shopee users',
#  'apasih suruh reset password terusudah ubah berhasil update sampe dicoba salah sampe reset x an tetep gabisa': "What if I told you to reset the password? After changing it, the update was successful until I tried it wrong until I reset it, but it still didn't work",
#  'cepat gratis': 'fast free',
#  'mencoba fitur nya': 'try its features',
#  'trimakasih topup va shopee gratis blm coba topup dana dll semoga gratis': "Thank you for free Shopee Va Topup. Haven't tried topping up funds etc. Hopefully it's free",
#  'seeabank burik kenaph setap medpatr lodg hapus ajah bos afliksi byh burik': 'seeabank dotted kenaph setap medpatr lodg just delete boss afliksi byh dotted',
#  'siiiippp': 'siiipppp',
#  'mantaaap': 'fire',
#  'mantapp gak pake admin tf': "great, don't use TF admin",
#  'senang transfer pake sll gratis smg pertahankan sukses sll': 'Happy to transfer using SSL for free, keep it successful always',
#  'wow aplikasi sempurna banget yasangat simpel mudah digunakanfitur fitur nya lengkap banget memudahkan pengguna nya transaksi yaaplikasi bermanfaat pengguna nya aplikasi lengkap ya tinggal ditambah menu itc memudahkan aplikasi jaringan stabil ya': "wow, the application is really perfect, it's very simple, easy to use, the features are complete, it really makes transactions easy for users, the application is useful for users, the application is complete, just add the ITC menu, it makes the application have a stable network, okay?",
#  'mantaff': 'mantaff',
#  'mudah utk pembayaran': 'easy for payment',
#  'bebas tf bank': 'free TF bank',
#  'harap atm yg nasabah': 'Please the ATM is a customer',
#  'mantap ni ewallet': 'This ewallet is solid',
#  'mudah mantaf ngaada biya oke dahh': 'easy to make beer okay dahh',
#  'bagus bertransaksi': 'good transaction',
#  'suka aplikasi': 'love the app',
#  'mudah bgt apa²': "it's really easy",
#  'good bgt dah': "that's really good",
#  'gg sea bank': 'gg sea bank',
#  'nggak login kali daftar gagal nunggu tolong perbaiki kali daftar gagal blokir ber': "can't log in when registering fails waiting please fix it when registering fails blocking ber",
#  'suka banget ya aplikasi memiliki manfaat mudah kawan kawanaplikasi nya ringan ngga memakai ram ponsel ya bagus nya aplikasi mudah gampang banget kawanaplikasi nya kendala digunakanfitur fitur tersaji lengkap membantu aplikasi ya': "I really like the application, it has easy benefits, friends, the application is light, doesn't use your phone's RAM, it's good, the application is really easy, friends, the application has problems using it, the features presented are complete, the application helps, OK?",
#  'bagus cepat': 'good fast',
#  'senang transaksi pakai': 'happy transaction using',
#  'aplikasi mudah': 'easy application',
#  'simpel cepat': 'simple fast',
#  'mudah n cepet pengirimannya ga hitungan menit langsung sukses tingkatkan kinerjanya recommended': 'easy and fast delivery in just a matter of minutes, immediately successful in improving performance, recommended',
#  'aplikasi yg bagus transaksi': 'good application for transactions',
#  'mempermudah transaksi': 'make transactions easier',
#  'oh keren untukku tambahkan kartu debit donk': 'oh cool for me to add a debit card please',
#  'suka banget': 'really like',
#  'pembayaran dgn aman n praktis': 'payments safely and practically',
#  'shevy arditiasari': 'shevy arditiasari',
#  'bagus aplikasinya': 'good application',
#  'pake jd mudah ngambil uang trasperan': 'The package makes it easy to transfer money',
#  'semoga berkembang lagiii': 'I hope it grows again',
#  'kesini ngelagg b tekan pin': 'come here lagging b press pin',
#  'lg mncoba cocok nga': 'the song is trying to fit or not',
#  'suka sngt mmbantu': 'very happy to help',
#  'membantu recomended': 'helpful, recommended',
#  'pokoknya oke': 'basically okay',
#  'transfer nya cepatada bunga hariannyayg amanhanya mengambil uang langsung tf rekening bank yg lainkrn atm nyabiaya transfer nya gratis': 'The transfer is fast, there is daily interest, it is safe, just take the money directly from another bank account because the ATM has a free transfer fee.',
#  'mudah transaksi semoga keamanan terjaga trimaksih': 'Easy transactions, hopefully security is maintained, thanks',
#  'baguss sukaa': 'nice, like it',
#  'belanja d shoope bayar pke biaya penanganan mantap lh pkoknya': "Shop at Shoppe, pay using handling fees, that's great anyway",
#  'gampang transfer': 'easy transfer',
#  'membantu transfer beda bank gratis': 'Helps with free transfers between banks',
#  'semoga konsisten dng keamanan terimakasih': 'Hopefully consistent with security, thank you',
#  'aplikasi bagus saran tinggal tambahkan logo diatas nama pemilik rekening mudah verfikasi aplikasi': "good application, suggestion, just add a logo above the account owner's name, easy to verify the application",
#  'semenjak pakai aplikasi benarbenar ngebantu bangetdan super gak ribet pengguna kaya akudan transfer gratis mikirin biaya adminyang bikin seneng bunga tabungan nya sampe fitur variasi nya tabungansakucelengandll overall si ngebantu bantu bangetapalagi suka berhubungan via transfer gsk mesti nunggu keamanan terjamin': "since using the application, it really helps a lot and it's super easy for users like me and the free transfer, think about the admin fee that makes me happy, the interest on the savings, the variety of features, savings, savings, etc. overall, the help is very helpful, what's more, I like to communicate via transfer, I don't have to wait for guaranteed security",
#  'senang mengunakan aplikasi sulit menerima transfereran mancanegara': 'happy to use the application, difficult to accept foreign transfers',
#  'mantap sih good job shopee': "That's great, good job Shopee",
#  'membantu memudah transaksi': 'helps make transactions easier',
#  'bagus transfer mudah cepat': 'good fast easy transfer',
#  'tanggal mohon dipindah keatas transfer screenshot': 'Please move the date to the top of the screenshot transfer',
#  'trbaik': 'best',
#  'jujur sih kali nya nemu aplikasi banking simpel sefleksibel download mudah transfer cepat mantap nya transfer online rekening bank variasi jenis tabungan nya jugatabungan utamasakudan nabung otomatis rekeningcelengan nya bunga keamanan terjamin udah pakai pin biometric loginsangat memudahkan bermanfaatterima kasih': "To be honest, it's the first time I've found a banking application that's as simple as it is flexible, easy to download, fast transfers, great, online transfers, bank accounts, various types of savings, also main savings, pocket and automatic savings accounts, piggy bank, interest, guaranteed security, biometric pin login, very easy, useful, thank you",
#  'pelayanan sistem cepat biaya transfer gratis fitur pelayanan yg jugasenang': 'fast system service, free transfer fees, service features that are also enjoyable',
#  'membantu trimakasih': 'help thank you',
#  'bank bagusss gak pake ribet makasih udah bikin sea bank': 'good bank, not complicated, thank you for making a bank',
#  'kereen aplikasinya': 'cool application',
#  'top biaya admin': 'top admin fees',
#  'transfer uang bank sea bank masuk ya uangnya tolong solusinya': 'Sea bank bank money transfer is coming in. Yes, the money, please provide a solution',
#  'transfer cepat non biaya': 'Fast transfer without fees',
#  'bagus terjamin aman': 'good guaranteed safe',
#  'top markotop pokoknya': 'top markotop basically',
#  'aplikasinya bagus transaksi berbeda aplikasi lainya': 'The application is good, the transactions are different from other applications',
#  'mencoba pembayaran transfer bank sea bank semoga aja diskon aplikasi sea bank': 'Try sea bank bank transfer payments, hopefully there will be a discount on the sea bank application',
#  'keren bngt': 'really cool',
#  'transfer bank gratis hemat msh dpt bunga hariannya': 'Free bank transfer saves and still gets daily interest',
#  'recomended': 'recommended',
#  'mudah banget salut': 'very easy to salute',
#  'mudah aman terpercaya': 'easy safe reliable',
#  'daftar tpi ktp dah daftar orang gak tau orangnya gimana daftar seabankpas daftar paket ktpmaaf nik andah terdaftarkatanya gimana balikinnya': "register but the ID card has already been registered, the person doesn't know how to register Seabankpas, register for the ID card package, sorry Nik, you are registered, he said how to get it back",
#  'terbaik gd pinjaman aja si yg': "It's best to just take a loan",
#  'mantap benget': 'really great',
#  'bgs': 'bgs',
#  'indonesia mantap kali mengecewajantranfer satset langsung nyampe cuman itungan detik pengalaman gangguan apapun rekomendasi banget mobilitas aman yg utama tampa biyaya tranfer bank digital gampang indonesia mengajukan pinjam x gak acc padal nabung udah inves': "Indonesia is always a disappointment, satset transfers arrive immediately in just a matter of seconds, experience any problems, really recommended, safe mobility, the main thing is that there are no costs, easy digital bank transfers, Indonesia applies for a loan, it doesn't get approved even though you have already invested in your savings",
#  'otp iya bagus otp nya masuknya': "OTP, yes, it's good that the OTP came in",
#  'mudah fitur lengkap': 'easy, complete features',
#  'lnjutkan': 'Continue',
#  'sy sdh sdh sy hapus aplikasi ya data yg masuk yg menyalah sy tdk bertanggung terima kasih informasijika kelak sy membutuhkan semoga promonya': 'I have already deleted the application, yes, the data entered was wrong, I am not responsible, thank you for the information, if I need it in the future, I hope you get a promotion',
#  'puas amanah': 'satisfied trust',
#  'kirim bank gratis jooosss': 'send bank free jooosss',
#  'mengadu gmail tiktok tiada respon adminnya rekening mati hapus nomor nya aktif rekening aktif bertransaksi shopee membayar topup salah rekening make protes kembalikan abaikan': 'Complaint Gmail Tiktok no response admin account is dead delete active number active account shopee transactions pay topup wrong account make protest return ignore ignore',
#  'apk nya membantu': 'the apk is helpful',
#  'mantapppp': 'greatpppp',
#  'transaksi mudah cepat': 'fast easy transaction',
#  'mudah fleksibilitas topup penarikan tabungannya': 'easy flexibility to top up and withdraw savings',
#  'terbaik mudah cepat': 'best easy fast',
#  'cepat akurat': 'fast accurate',
#  'gratis': 'free',
#  'nyaman bagus bgt': 'very comfortable',
#  'perkara hapus aplikasi log in ulang ga rumit laporannga ga bank': 'The case of deleting the re-login application is not complicated, the report is not bankable',
#  'lumayan lumanyun': 'quite impressive',
#  'sayangnya membantu refund saldo yg terkirim penipu online chat c nya bantu dm ig nya respon mengetik chat kayaknya langsung blokir penyebabnya penipuan online marak kayaknya rekening bank indonesia membantu repundbalikin saldonya timbulnya penipu online bertambah kaya raya yg tergiur penipu online': 'Unfortunately, helping to refund balances sent by online fraudsters, chat with C, help with IG DMs, respond to typing chat, it seems like they immediately block it, the reason is that online fraud is rampant, it seems that Indonesian bank accounts are helping to recover balances, online fraudsters are getting richer, those who are tempted by online fraudsters',
#  'semoga': 'Hopefully',
#  'gak login akun hp': "I can't log in to my cellphone account",
#  'bagus simple memudahkan bertransaksitapi tingkatkan lindungi pengguna': 'good, simple, makes transactions easier but increases user protection',
#  'aplikasi yg brat': 'great application',
#  'bgyass': 'bgyass',
#  'sea bank cemerlang fiturnya super simple diskon promo nya dapatkanuntuk sistem nya tampilannya sederhana mudah aplikasi mempermudah kebanyakan pengguna nyadalam nya bermanfaat sekalimemiliki kegunaan didalam nyasalah nya kemudahan transfer uang top up salah kelebihan aplikasi': 'sea \u200b\u200bbank is brilliant, the features are super simple, the promo discounts are available for the system, the appearance is simple, the application makes it easy for most users, the inside is very useful, the benefits are useful, the ease of transferring top up money is one of the advantages of the application',
#  'transaksi tercepat sejarah': 'Fastest transaction history',
#  'gak nyangka banget aplikasi nyaman jarang menemukan aplikasi seistimewa fiturnya mewah grafiknya bagus membikin aplikasi mewah merekomendasikan nya penyimpanan uang amanah terpercaya dijamin nyaman memakainya menabung gokil banget': "I didn't expect it to be such a convenient application. It's rare to find an application as special as its features are luxurious. The graphics are good. This makes it a luxurious application. Recommend it, safe, reliable money storage, guaranteed to be comfortable using it, saving is really crazy.",
#  'keren banget': 'very cool',
#  'ringkas': 'brief',
#  'best patner': 'best partner',
# ...
#  'istimewa transaksi cepat': 'special fast transaction',
#  'membatu bertransaksi': 'help with transactions',
#  'love banget deh customer service helpful banget akun saldo rekening minimtt thank you yaaa minsea': 'I really love the customer service, very helpful, minimal account balance, thank you, Minsea',
#  'terbaikkkk': 'the best',
#  'bagus ditingkatkan': 'good improvement',
#  'pelayanan nya': 'his service',
#  'puas pakai': 'satisfied with use',
#  'membantu bank atm': 'help bank ATM',
#  'aman nyaman pokoknya gk pakek ribet': "safe, comfortable, just don't use anything complicated",
#  'aplikasi yg mudah mudah utk transfer topup dll': 'easy application for top up transfers etc',
#  'free biaya transfer bankproses cptsmg ttp dprtahankan layanan tingkatkan': 'free bank transfer fees, cptsmg process but service improvements are maintained',
#  'mantap bener': 'really good',
#  'aplikasi perbankan mantap': 'great banking application',
#  'makasih sea banksangat membantu': 'Thank you Sea Bank, very helpful',
#  'mantapsss': 'greatsss',
#  'mudah transaksi': 'easy transaction',
#  'biaya admin gratis sukamakasih': 'free admin fees, thanks',
#  'dwonload knp kode y ga kirm kta y bgus login ja ssh': "Why don't you download the code, it's good to log in with SSH",
#  'blm dicoba pakai transaksi mudahan baguss': "Haven't tried using the transaction yet, hopefully it's good",
#  'terimakasih cepat transfernya ngk menunggu': 'Thank you, fast transfer, no waiting',
#  'enak penggunaan nya semoga cepet limit pinjam': "It's nice to use, hopefully the loan limit will be quick",
#  'jos gandos': 'jos gandos',
#  'bagus sayang blm fitur pinjaman': "Good, unfortunately there's no loan feature yet",
#  'kali transaksi pake semoga ajh kedepannya mempermudah pemakainya transaksi sehari²': 'I hope you make transactions using it in the future, making it easier for users to make daily transactions',
#  'gimana login akun sea bank nomor yg terdaftar sea bank uda mati gak mintak kode otp nya mohon bantu sahabat': "How to log in to a Seabank account, the number registered with Seabank is dead, I don't ask for the OTP code, please help, friend",
#  'mantap versi': 'great version',
#  'terimakasih memudahkan dlm transaksi transaksi kemana aja gak pake dramaakkk': 'Thank you, it makes it easy to carry out transactions anywhere without using Dramaqu',
#  'prose transaksi cepat yg hebat trfer biaya gratis': 'Great fast transaction process, free transfers',
#  'terimakasih membantu': 'thank you for helping',
#  'menyenangkan': 'pleasant',
#  'bagus bnget': 'really good',
#  'memuaskan kalo aja tp recomendet pokoknya sukses trus sea bank mantap': 'Satisfying at least, but recommended, the main thing is that it is successful and Sea Bank is great',
#  'aplikasi nya bagus fitur gratis transfer nya bank yg': 'A good application with free bank transfer features',
#  'sengaja kasih bintang biar baca tf sea bank dana nominal jt sampe masuk masuk penyelesaian nya sea bank': "I deliberately gave it a star so that it read TF Sea Bank with a nominal amount of JT until it entered Sea Bank's settlement",
#  'biaya transfer bank manapun free': 'Any bank transfer fee is free',
#  'memudahkan transaksi online suku bunga yg menguntungkan aplikasi memiliki keunggulan didalamnya salah satunya pengisian saldo e walet mengeluarkan biaya tambahan aplikasi perbankan digital yg beredar menurutku yg bagus bersahaja event hadiah didalamnya yg pengguna saldo online mantplah': 'Facilitates online transactions, profitable interest rates, the application has advantages in it, one of which is topping up the e-swallow balance, removing additional fees, the digital banking application in circulation, in my opinion, which is good, simple, the prize event in it for online balance users is great',
#  'terimakasih mudah transfer': 'thank you easy transfer',
#  'bunga naikan': 'increased interest',
#  'asyik mengunakan sea bank': 'fun to use seabank',
#  'mantab kali pakai': 'great to use',
#  'aplikasi bank digital satset kirim kemana gratis aplikasinya ringan': 'satset digital bank application send anywhere for free, the application is light',
#  'transaksi cepatterimakasih': 'fast transaction, thank you',
#  'transaksi gratis': 'free transactions',
#  'mendaftar verifikasi foto ktp otomatis capek ngulang ngulang terfoto foto mending foto manual aja': 'Register for automatic photo verification. Tired of repeating the photo. Instead, just take a manual photo',
#  'gimana ni aplikasi pertamanya doang lancar susah login': 'How come the first application is smooth and difficult to login',
#  'very good application and it very easy to use it': 'very good application and it very easy to use it',
#  'moga jaya': 'good luck',
#  'aq suka sm aplikasi smoga fiturnya bagus kedepannya maju trus': 'I like the application, I hope the features are good, it will be developed in the future',
#  'bank digital terbaik simpel mudah yabagus bertransaksi online yahal dirasakan mendownload aplikasi yamenurut aplikasi bagus ya tinggal ditambah menu pelengkap nya utc memudahkan nya jaringan stabil yaselebih nya bagus nyaman ya kawan kawan': "best digital bank, simple, easy, good for online transactions, yes, you feel like downloading the application, according to the application, it's good, just add the complementary menu, UTC, to make it easier, the network is stable, the rest is good, comfortable, friends",
#  'baguss aps nya': 'the app is good',
#  'mudah terimakasih': 'easy thanks',
#  'tranfer kebank lainawal normal sekarng gk bstolong diperbaiki': "Other bank transfers were normal at first but now they can't, please fix it",
#  'segi tampilan aplikasi mantab kyc nya gak oke deh tf bank kasih gratis tf x mabtab': "In terms of the appearance of the KYC application, it's not okay, TF Bank gives free TF x Mabtab",
#  'menyenangkan hati': 'pleasing',
#  'tingkat kecepatan n kemudahan transaksi lupa suku bunga nya perbesarhehe': 'the level of speed and ease of transactions, forget about increasing interest rates, hehe',
#  'transaksi lancar gratis adminnya bunganya keren rekomended banget dah': 'Smooth transaction, admin free, cool interest, really recommended',
#  'cepat bagusss': 'fast, good',
#  'oke gratis suka bnget': "okay, it's free, I really like it",
#  'terbaik si kalo shopeee': 'the best for shopee',
#  'mudah gampang transaksi': 'easy and easy transaction',
#  'membantu apapun tingkatkan kwalitas nya': 'any help to improve the quality',
#  'aplikasi nya bagus': 'the application is good',
#  'seabankudah digunakansukses untk': 'seabankkuhas been used successfully for',
#  'gratis top up ewallet': 'free ewallet top up',
#  'membantu gratis adm': 'help free admin',
#  'mudahbunga': 'fruitful',
#  'kecewa dirugikan kemaren transfer rekening e wallet terkirim tanggung nya': 'Disappointed at the loss yesterday, the e-wallet account transfer was sent at his responsibility',
#  'okee': 'okay',
#  'smoga kartu fisik nya': "Hopefully it's a physical card",
#  'mantap bos ku': 'great my boss',
#  'langsung sat set': 'set straight away',
#  'mantab baguss': 'great, good',
#  'mudah banget': 'really easy',
#  'mantap membantu bgt': 'really helpful',
#  'tlng bos dibenerin top ap dana kiriman sukss tp gk': 'pls boss correct the top ap funds successful delivery but no',
#  'adakan cabang bank indonesia kendala apapun langsung koordinasi bank': 'hold a Bank Indonesia branch, whatever obstacles arise, direct bank coordination',
#  'optimalkan': 'optimize',
#  'bagus cepat membuka rekeningnyag ribet': 'good for quickly opening complicated accounts',
#  'mudahkan pengguna kayak': 'make things easier for users',
#  'kuota tf gratis bulannya wa wa uang hilang ngg ad buku tabungan keamanan nya sih tanda kutip': 'free monthly TF quota, wa wa money lost, no security passbook, quotes',
#  'kami juni sya mlakukan trx tf dr apk propana k rek sya dg tujuan berbelanja d shopee trx tf dr apk propana sukses berhsil saldo tdk masuk k rek pdhl dr pengirim apk propana sukses sdgkn sya k tdk bantu pengecekan krn pasif sbg penerima dana menyarankan sya pengirim stlh sya k pengirim ktax saldo sdh terpotong trx sukses': "In June, I did a trx tf from the propane apk on my account with the aim of shopping on shopee trx tf from the propane apk, it was successful, the balance didn't go into the account even though the sender of the propane apk was successful, but I didn't help with the checking because I was passive as a recipient of the funds, suggesting that I was the sender after I'm sure the Ktax sender's balance has been deducted and the trx was successful",
#  'simple': 'simple',
#  'membabtu': 'helping',
#  'mantap nya transfer potongan alias garatis': "It's great to transfer discounts, aka it's free",
#  'sungguh kren': 'what a crane',
#  'aplikasi suka benci gara trx pulsa g masuk² udh xjam penanganan sulit udah bosan basi c membantu malas menghapus akun pulsa g msuk saldo berkurang': "the application likes to hate it because the trx credit hasn't come in, it's been difficult handling for x hours, I'm bored, it's stale, c helps, I'm too lazy to delete my credit account, the balance hasn't gone in, the balance has decreased",
#  'kerennnn': 'kerennnn',
#  'apknya mudah dipahami cuman akunku login gk ya': 'The apk is easy to understand, but is my account logged in or not?',
#  'bagus aplikasih mua ribet': 'good application, less complicated',
#  'senang pengiriman cepat admin pokoknya nomor e walet': 'happy with fast delivery admin, just e wallet number',
#  'ferry ggod': 'ferry good',
#  'lumayan': 'reasonable',
#  'layanannya bagus': 'the service is good',
#  'tahap': 'level',
#  'the best pokoknya': 'the best basically',
#  'terbantu': 'helped',
#  'cepat terpercaya amanah': 'fast reliable trustworthy',
#  'mantap langsung': 'straight away',
#  'maannntttaaappp': 'maannntttaaappp',
#  'good app': 'good app',
#  'yg terbaik sukses sllu': 'the best is always successful',
#  'semoga bermanfaat orang': "I hope it's useful for people",
#  'bug kamera foto id kamera gelap hitam kirain kamera yg rusak gak tau nya ngebug perbaiki': "photo camera bug, ID camera, dark black, thought the camera was broken, didn't know how to fix the bug",
#  'seneng seebank sukses seebank': 'happy seebank success seebank',
#  'mantap mudah simpel': 'great easy simple',
#  'keren bgt gokil': 'really cool and crazy',
#  'simplecepataman': 'simplecepataman',
#  'pembayaran pinjaman elit pinjaman sulit': 'elite loan payments difficult loans',
#  'ok banget membantu transaksi pinjamannya': 'OK, really helped with the loan transaction',
#  'gara gara no hilang ga pakai betulin ribet bener tolong passwod aja ga otp': "because it's not lost, I don't use it properly, it's really complicated, please just password, not otp",
#  'aplikasi mendukung mudah praktis': 'application supports easy practical',
#  'joss wes': 'joss wes',
#  'aplikasi nya mantap prose cepat': 'the application is great, the process is fast',
#  'trf gratis bank': 'trf free bank',
#  'membantu bertransaksi': 'help with transactions',
#  'g tf n top up ya': 'g tf n top up ya',
#  'mudah dipahami': 'easy to understand',
#  'cepat bertransaksi secepat kilat rating kasih bintang muncul spinjamnya kasih agi bintang': 'Fast transactions as fast as lightning. The star rating appears and the star rating appears',
#  'mantulll': 'mantulll',
#  'enak gak ribet': 'delicious, not complicated',
#  'mantap aplikasi perbankan star deh yg ngomong': "The Star banking application is great, I'm talking",
#  'membantu transaksi layanan': 'assist with service transactions',
#  'transfer gampang mudah': 'easy easy transfer',
#  'mempermudah transfer': 'makes transfers easier',
#  'transfer potongan': 'transfer deductions',
#  'pelerrr': 'pelerrr',
#  'suka bgt gratis admin': "really like it, it's free admin",
#  'bagus mudah pahami kekurangan pitur mudah pembayaran blm atmnya': 'good, easy to understand the shortcomings of the easy payment feature without an ATM',
#  'makasih senang transaksi': 'Thank you, happy transaction',
#  'ui nya udh nyaman': 'The UI is comfortable',
#  'jod': 'jod',
#  'pa banget bertransaksi yasimpel mudah yafitur fitur nya lengkap komplit ya pengguna nya mudah nya membantu ya bermanfaat banget kawansejauh aplikasi kendala punpastikan memiliki aplikasi utk kemudahan bertransaksi ya kawan kawan': "it's really easy to make transactions, it's simple and easy, the features are complete, it's easy to use, it's helpful, it's really useful, friends, as far as application problems, make sure you have an application for easy transactions, friends",
#  'mantap kalo topup pulsa data harganya mahal gk jual': "It's great that if you top up your data credit it's expensive and don't sell it",
#  'terima kasih': 'Thank You',
#  'ayo rilis kartu debitdan tarik tunai mesin atm admin biar gk kalah saing tetangga sebelahtetangga sebelah gratis tranfer bankdan gratis tarik tunai mesin atm xbulan': "let's release debit cards and cash withdrawals from admin ATM machines so you don't lose out to your next door neighbors, free bank transfers and free cash withdrawals from ATM machines x month",
#  'bantu pinjam gnna': 'help borrow Gnna',
#  'memudahkan love bget': 'make it easier to love bget',
#  'mudah cepat transaksinya gratis pinjam uang bungan kompetitif limit pinjamannya naikin donk': 'Easy, fast transactions, free money to borrow, competitive interest, increase the loan limit',
#  'cepat ngak potongan pokoknya mantul banget': 'fast ngak cut anyway very bouncing',
#  'sukaa siiih praktis': 'I like being practical',
#  'cepat biaya admin': 'fast admin fees',
#  'gratis tranfer rtgs': 'free RTGS transfers',
#  'bank oke': 'couch okay',
#  'plis berubah': 'please change',
#  'pengguna suka banget semoga berkembang ya': 'Users really like it, hopefully it will develop',
#  'knp hadiah kirim byk syarat': 'Why do gifts send so many conditions?',
#  'mudah dgunakan': 'easy to use',
#  'dicintai masyarakat indonesia': 'loved by the Indonesian people',
#  'buruk transaksi masuk maksudnya coba tolong konfirmasi saldo': 'Bad incoming transaction means please try to confirm the balance',
#  'bagus enak mudah pemakaian nya terimakasih': 'nice, easy to use, thank you',
#  'enak banget gak bayar admin tf beda bank': "it's really nice not to pay admin tf from different banks",
#  'sanagat puas': 'very satisfied',
#  'cepat no leletterimakasih': 'fast, no slow, thank you',
#  'lumayan nyaman gratis admin': 'quite comfortable, admin free',
#  'membuka rec': 'open rec',
#  'nunggu mantap baguss': 'good wait',
#  'gk bonus rb': 'gk bonus rb',
#  'baguus ribet n prose cepat auto notif mudah ngecek': 'baguus complicated n process fast auto notif easy to check',
#  'praktis mudah': 'practically easy',
#  'fast n simple': 'fast n simple',
#  'cpt mudah': 'very easy',
#  'pa banget aplikasi simpel mudah yadari segi tampilan nya ul nya membantu memudahkan pengguna nya yapuas banget aplikasi yadari segi fitur lengkap kemudahan ya kawansejauh menunggunakan aplikasi bug membantu banget aplikasi yaproses transaksi cepat mudah banget ya': "it's really a simple, easy application, yes, in terms of appearance, the ul helps make it easier for users, yes, the application is very satisfied, yes, in terms of complete features, it's easy, friends, as long as you wait for the bug application, the application is really helpful, the transaction process is really fast, it's really easy, okay?",
#  'muantab sea bank': 'muantab sea bank',
#  'smoga aman nabung': 'I hope you save safely',
#  'mudah cepat aman gratis': 'easy fast safe free',
#  'bermanfaat pakai membantu tranfer belanjaan online rumah': 'Useful to help with online home shopping transfers',
#  'bagus mandiri menabung nya maaf turunkan bintang full bank tranfer nya maaf rekening salah rekening yg salah': 'good, independent, the interest is sorry, lower the star, full bank transfer, sorry, wrong account, wrong account',
#  'simpel memuaskan': 'simple and satisfying',
#  'bagus cepat mohon pertahankan aplikasinya': 'good fast please maintain the application',
#  'mode gelap': 'dark mode',
#  'sungguh senangnya': 'really happy',
#  'akun gw log out pa login disuruh verifikasi ktp gimana tolong': 'I logged out of my account when I logged in and was asked to verify my ID card, please',
#  ...}

# %%
data.replace(translations, inplace = True)
data
# Out:
#                                                 content
# 0                                                    in
# 1                                                   top
# 2     application for children with visual disabilities
# 3                                                 solid
# 4     The best user satisfaction, apart from the ben...
# ...                                                 ...
# 3479                                        simple free
# 3480                      No problem is easy, it's easy
# 3481                         fast accurate transactions
# 3482  Fast service, not inferior to HTI liquid inter...
# 3483                          Min deposit interest rate
#
# [3484 rows x 1 columns]

# %%
data.to_excel('/content/drive/MyDrive/DataFix/Label/SastSeabank_DataTranslated.xlsx', index=False)

# %% [markdown]
# # Memisahkan Data Menjadi Set Train (Pelatihan) dan Set Test (Pengujian)

# %%
#SPLIT DATA
import pandas as pd

dataset = pd.read_excel('/content/drive/MyDrive/DataFix/Label/SastSeabank_DataTranslated.xlsx')

# Hitung jumlah baris dalam dataset
num_rows = len(dataset)

# Hitung jumlah baris yang akan digunakan sebagai pelatihan (disini 50%)
train_size = int(0.5 * num_rows)

# Bagi dataset menjadi subset pelatihan dan pengujian
train_data = dataset[:train_size]
test_data = dataset[train_size:]

# Simpan subset pelatihan ke dalam file xlsx
train_data.to_excel('/content/drive/MyDrive/DataFix/Label/SastSeabank_DataTrainEnglish.xlsx', index=False)

# Simpan subset pengujian ke dalam file xlsx
test_data.to_excel('/content/drive/MyDrive/DataFix/Label/SastSeabank_DataTestEnglish.xlsx', index=False)

# %%
# !pip install Textblob
# Out:
# Requirement already satisfied: Textblob in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.10/dist-packages (from Textblob) (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->Textblob) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->Textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->Textblob) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->Textblob) (4.66.4)

# %%
from textblob import TextBlob

# %%
train_data
# Out:
#                                                 content
# 0                                                    in
# 1                                                   top
# 2     application for children with visual disabilities
# 3                                                 solid
# 4     The best user satisfaction, apart from the ben...
# ...                                                 ...
# 1737                                the process is fast
# 1738           Send it wherever it's easy and it's free
# 1739                                     fast responsif
# 1740                                          great cut
# 1741                                          satisfied
#
# [1742 rows x 1 columns]

# %% [markdown]
# # Analisis Sentimen pada Data Train (Pelatihan)

# %%
data_content = list(train_data['content'])
polaritas = 0

status = []
total_positif = total_negatif = total = 0

for i, tweet in enumerate(data_content):
    analysis = TextBlob(tweet)
    polaritas += analysis.polarity

    if analysis.sentiment.polarity > 0.0:
        total_positif += 1
        status.append('Positif')
    else:
        total_negatif += 1
        status.append('Negatif')

    total += 1

print(f'Hasil Analisis Data:\nPositif = {total_positif}\nNegatif = {total_negatif}')
print(f'\nTotal Data : {total}')
# Out:
# Hasil Analisis Data:
# Positif = 1182
# Negatif = 560
#
# Total Data : 1742

# %%
status = pd.DataFrame({'Label': status})
train_data['Label'] = status
train_data
# Out:
# <ipython-input-17-ddb1f5b9bf00>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['Label'] = status
#                                                 content    Label
# 0                                                    in  Negatif
# 1                                                   top  Positif
# 2     application for children with visual disabilities  Negatif
# 3                                                 solid  Negatif
# 4     The best user satisfaction, apart from the ben...  Positif
# ...                                                 ...      ...
# 1737                                the process is fast  Positif
# 1738           Send it wherever it's easy and it's free  Positif
# 1739                                     fast responsif  Positif
# 1740                                          great cut  Positif
# 1741                                          satisfied  Positif
#
# [1742 rows x 2 columns]

# %% [markdown]
# # Menyeimbangkan Data (Balancing Data)

# %%
# Memisahkan data berdasarkan label
positif_data = train_data[train_data['Label'] == 'Positif']
negatif_data = train_data[train_data['Label'] == 'Negatif']

# %%
# Menentukan jumlah sampel minimum di 2 kelas kelas
min_samples = min(total_positif, total_negatif)

# %%
from sklearn.utils import resample

# %%
# Melakukan penyeimbangan data dengan undersampling
positif_data_resampled = resample(positif_data, replace=False, n_samples=min_samples, random_state=42)
negatif_data_resampled = resample(negatif_data, replace=False, n_samples=min_samples, random_state=42)

# %%
# Menggabungkan kembali data yang telah disusun ulang
balanced_data = pd.concat([positif_data_resampled, negatif_data_resampled])

# %%
data_content_balanced = list(balanced_data['content'])
polaritas_balanced = 0

status_balanced = []
total_positif_balanced = total_negatif_balanced = total_balanced = 0

for i, tweet in enumerate(data_content_balanced):
    analysis = TextBlob(tweet)
    polaritas_balanced += analysis.polarity

    if analysis.sentiment.polarity > 0.0:
        total_positif_balanced += 1
        status_balanced.append('Positif')
    else:
        total_negatif_balanced += 1
        status_balanced.append('Negatif')

    total_balanced += 1

print(f'Hasil Analisis Data Setelah Penyeimbangan:\nPositif = {total_positif_balanced}\nNegatif = {total_negatif_balanced}')
print(f'\nTotal Data Setelah Penyeimbangan: {total_balanced}')
# Out:
# Hasil Analisis Data Setelah Penyeimbangan:
# Positif = 560
# Negatif = 560
#
# Total Data Setelah Penyeimbangan: 1120

# %%
train_data.to_excel('/content/drive/MyDrive/DataFix/Label/SastSeabank_DataTrainEngLabeled.xlsx',index=False)

# %%
balanced_data.to_excel('/content/drive/MyDrive/DataFix/Label/SastSeabank_DataTrainEngLabeledBalanced.xlsx', index=False)

# %% [markdown]
# # Menerjemahkan Data yang Telah Diseimbangkan ke Dalam Bahasa Indonesia

# %%
import pandas as pd
from googletrans import Translator

def translate_to_indonesian(text):
    translator = Translator()
    result = translator.translate(text, src='en', dest='id')
    return result.text

def translate_excel_column(input_file, output_file, sheet_name, column_name):
    df = pd.read_excel(input_file, sheet_name=sheet_name)
    df[column_name] = df[column_name].apply(translate_to_indonesian)

    with pd.ExcelWriter(output_file) as writer:
        df.to_excel(writer, index=False, sheet_name=sheet_name)
    print("Translation complete. Translated data saved to a new Excel file!")

# Example usage
input_file = '/content/drive/MyDrive/DataFix/Label/SastSeabank_DataTrainEngLabeledBalanced.xlsx'
output_file = '/content/drive/MyDrive/DataFix/Label/SastSeabank_DataTrainIndLabeledBalanced.xlsx'
sheet_name = 'Sheet1'  # Change to your sheet name
column_name = 'content'  # Change to the name of the column you want to translate

translate_excel_column(input_file, output_file, sheet_name, column_name)
# Out:
# Translation complete. Translated data saved to a new Excel file!

# %%
import pandas as pd
from googletrans import Translator

def translate_to_indonesian(text):
    translator = Translator()
    result = translator.translate(text, src='en', dest='id')
    return result.text

def translate_excel_column(input_file, output_file, sheet_name, column_name):
    df = pd.read_excel(input_file, sheet_name=sheet_name)
    df[column_name] = df[column_name].apply(translate_to_indonesian)

    with pd.ExcelWriter(output_file) as writer:
        df.to_excel(writer, index=False, sheet_name=sheet_name)
    print("Translation complete. Translated data saved to a new Excel file!")

# Example usage
input_file = '/content/drive/MyDrive/DataFix/Label/SastSeabank_DataTestEnglish.xlsx'
output_file = '/content/drive/MyDrive/DataFix/Label/SastSeabank_DataTestIndo.xlsx'
sheet_name = 'Sheet1'  # Change to your sheet name
column_name = 'content'  # Change to the name of the column you want to translate

translate_excel_column(input_file, output_file, sheet_name, column_name)
# Out:
# Translation complete. Translated data saved to a new Excel file!
