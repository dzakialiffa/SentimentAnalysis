# %%
#mounting google drive

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
# Memuat data dari file
df = pd.read_csv('/content/drive/MyDrive/Portfolio/Sentiment Analysis User Reviews App GetContact/GetContact.csv')

# %%
# Eksplorasi data
df.head() # Menampilkan beberapa baris pertama data
# Out:
#                                reviewId         userName  \
# 0  28ac9151-c286-418a-ab58-4ca4ea5ec0e5      Lisakuuu 30
# 1  1b4d6df7-ec52-4fa4-9a97-27642bfbff8f  mardika guntoro
# 2  2bc02d48-566b-43eb-a40a-6d86566a52f1       Aidah Nada
# 3  c38ad71f-ee86-4958-8199-cf9ec1ad06db    Rinto Harahap
# 4  b46f9539-fe00-4e76-b240-d6b2929c7998   pencinta kicau
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  nomor saya gbsa verifikasi udh puluhan kali di...      3              0
# 1  Some number can refuse to be seen on their tag...      2              0
# 2            Kembalikan getcontact seperti dulu woyy      1              0
# 3                                               baik      3              0
# 4      Dulu gratis skrg berbayar.. Uninstall aja lah      1              1
#
#   reviewCreatedVersion                   at  \
# 0                7.3.1  2024-12-09 23:49:21
# 1                6.9.0  2024-12-09 22:36:59
# 2                  NaN  2024-12-09 21:58:18
# 3                7.3.1  2024-12-09 21:30:55
# 4                7.3.1  2024-12-09 20:50:37
#
#                                         replyContent            repliedAt  \
# 0  Halo, Jika Anda kesulitan mendapatkan kode ver...  2024-12-10 07:51:53
# 1                                                NaN                  NaN
# 2                                                NaN                  NaN
# 3                                                NaN                  NaN
# 4  Tim Getcontact telah menerima komentar Anda da...  2024-12-10 07:33:07
#
#   appVersion
# 0      7.3.1
# 1      6.9.0
# 2        NaN
# 3      7.3.1
# 4      7.3.1

# %%
# Membaca dataset CSV

# Mengecek baris yang mengandung link di kolom 'content'
rows_with_links = df[df['content'].str.contains(r'http\S+|www.\S+', na=False)]

# Mengecek baris yang mengandung simbol di kolom 'content'
rows_with_symbols = df[df['content'].str.contains(r'[^\w\s]', na=False)]

# Mengecek baris yang mengandung whitespaces di kolom 'content'
rows_with_whitespaces = df[df['content'].str.contains(r'\s+', na=False)]

# Mengecek baris yang mengandung angka di kolom 'content'
rows_with_numbers = df[df['content'].str.contains(r'\d+', na=False)]

# Menampilkan hasil
print("Baris yang mengandung link di kolom 'konten_ulasan':")
print(rows_with_links[['content']])
print(f"Jumlah baris yang mengandung link: {len(rows_with_links)}\n")

print("Baris yang mengandung simbol di kolom 'content':")
print(rows_with_symbols[['content']])
print(f"Jumlah baris yang mengandung simbol: {len(rows_with_symbols)}\n")

print("Baris yang mengandung whitespaces di kolom 'content':")
print(rows_with_whitespaces[['content']])
print(f"Jumlah baris yang mengandung whitespaces: {len(rows_with_whitespaces)}\n")

print("Baris yang mengandung angka di kolom 'content':")
print(rows_with_numbers[['content']])
print(f"Jumlah baris yang mengandung angka: {len(rows_with_numbers)}\n")

# Menampilkan data dengan indeks 2494, jika ada
def check_and_print(index, df):
    if index in df.index:
        print(f"Data pada indeks {index}:")
        print(df.loc[index, 'content'])
    else:
        print(f"Data pada indeks {index} tidak ditemukan atau tidak memenuhi kondisi.\n")
# Out:
# Baris yang mengandung link di kolom 'konten_ulasan':
#                                                 content
# 2677  Apk gajelass asww, pdhl blm prnh nyari tag tp ...
# Jumlah baris yang mengandung link: 1
#
# Baris yang mengandung simbol di kolom 'content':
#                                                 content
# 1     Some number can refuse to be seen on their tag...
# 4         Dulu gratis skrg berbayar.. Uninstall aja lah
# 6                                        mantap.....😍😍😍
# 7     Tidak bisa kebuka aplikasinya sudah saya coba ...
# 8                    Makin kesini apknya makin kesana,.
# ...                                                 ...
# 5153    Bagus apanya duluu bagus sekarang bayar payah!!
# 5155  Sebulan cuma pake 1 kali 2 kali tp harus bayar...
# 5156  Baru berlangganan gaada 5 menit tiba tiba log ...
# 5158  Kenapa masih di tarik otomatis dari rek untuk ...
# 5169  Awal nya sih bagus aja,tapi lama2 maksa premiu...
#
# [1901 rows x 1 columns]
# Jumlah baris yang mengandung simbol: 1901
#
# Baris yang mengandung whitespaces di kolom 'content':
#                                                 content
# 0     nomor saya gbsa verifikasi udh puluhan kali di...
# 1     Some number can refuse to be seen on their tag...
# 2               Kembalikan getcontact seperti dulu woyy
# 4         Dulu gratis skrg berbayar.. Uninstall aja lah
# 7     Tidak bisa kebuka aplikasinya sudah saya coba ...
# ...                                                 ...
# 5168  Aku udah mencoba masuk beberapa kali lebih len...
# 5169  Awal nya sih bagus aja,tapi lama2 maksa premiu...
# 5170  Saya kasih bintang 4 aja kalau tau hasilnya ba...
# 5171  pelit lu ngeliat tag orang aja harus premium dulu
# 5173  ditunggu sebulan lebih kagak baljk2 anjg premi...
#
# [4252 rows x 1 columns]
# Jumlah baris yang mengandung whitespaces: 4252
#
# Baris yang mengandung angka di kolom 'content':
#                                                 content
# 9     menyesal sekali langganan langsung banyak moto...
# 51    bener kayak dulu mala di bikin berbayar semua ...
# 53    aplikasi paling burug sepanjang masa, semua fi...
# 55    sekarang tambah minus banyak. udah cuma dibate...
# 57                       Gunung anyar jaya Safira no 11
# ...                                                 ...
# 5162  pemgalaman saya uang saya hilang 20 ribu tanpa...
# 5163       Kenapa harus premium dlu kalo mau liat nama2
# 5169  Awal nya sih bagus aja,tapi lama2 maksa premiu...
# 5170  Saya kasih bintang 4 aja kalau tau hasilnya ba...
# 5173  ditunggu sebulan lebih kagak baljk2 anjg premi...
#
# [334 rows x 1 columns]
# Jumlah baris yang mengandung angka: 334

# %%
df.info()  # Informasi tentang tipe data dan jumlah nilai non-null dalam setiap kolom
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5174 entries, 0 to 5173
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              5174 non-null   object
#  1   userName              5174 non-null   object
#  2   userImage             5174 non-null   object
#  3   content               5174 non-null   object
#  4   score                 5174 non-null   int64
#  5   thumbsUpCount         5174 non-null   int64
#  6   reviewCreatedVersion  3606 non-null   object
#  7   at                    5174 non-null   object
#  8   replyContent          2637 non-null   object
#  9   repliedAt             2637 non-null   object
#  10  appVersion            3606 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 444.8+ KB

# %%
# Menghapus kolom yang tidak diperlukan untuk analisis
df = df.drop(columns=[
    'reviewId', 'userName', 'userImage', 'score', 'thumbsUpCount', 'reviewCreatedVersion', 'at', 'replyContent', 'repliedAt', 'appVersion'
])
df.head()
# Out:
#                                              content
# 0  nomor saya gbsa verifikasi udh puluhan kali di...
# 1  Some number can refuse to be seen on their tag...
# 2            Kembalikan getcontact seperti dulu woyy
# 3                                               baik
# 4      Dulu gratis skrg berbayar.. Uninstall aja lah

# %%
import re
# Menghapus karakter '@' dari content_remove_link
df['content_remove_at'] = df['content'].apply(lambda x: re.sub(r'@', '', str(x)))
df
# Out:
#                                                 content  \
# 0     nomor saya gbsa verifikasi udh puluhan kali di...
# 1     Some number can refuse to be seen on their tag...
# 2               Kembalikan getcontact seperti dulu woyy
# 3                                                  baik
# 4         Dulu gratis skrg berbayar.. Uninstall aja lah
# ...                                                 ...
# 5169  Awal nya sih bagus aja,tapi lama2 maksa premiu...
# 5170  Saya kasih bintang 4 aja kalau tau hasilnya ba...
# 5171  pelit lu ngeliat tag orang aja harus premium dulu
# 5172                                              Bagus
# 5173  ditunggu sebulan lebih kagak baljk2 anjg premi...
#
#                                       content_remove_at
# 0     nomor saya gbsa verifikasi udh puluhan kali di...
# 1     Some number can refuse to be seen on their tag...
# 2               Kembalikan getcontact seperti dulu woyy
# 3                                                  baik
# 4         Dulu gratis skrg berbayar.. Uninstall aja lah
# ...                                                 ...
# 5169  Awal nya sih bagus aja,tapi lama2 maksa premiu...
# 5170  Saya kasih bintang 4 aja kalau tau hasilnya ba...
# 5171  pelit lu ngeliat tag orang aja harus premium dulu
# 5172                                              Bagus
# 5173  ditunggu sebulan lebih kagak baljk2 anjg premi...
#
# [5174 rows x 2 columns]

# %%
# Menghapus link dari data content
df['content_remove_link'] = df['content_remove_at'].apply(lambda x: re.sub(r'http\S+|www.\S+', '', str(x)))
df
# Out:
#                                                 content  \
# 0     nomor saya gbsa verifikasi udh puluhan kali di...
# 1     Some number can refuse to be seen on their tag...
# 2               Kembalikan getcontact seperti dulu woyy
# 3                                                  baik
# 4         Dulu gratis skrg berbayar.. Uninstall aja lah
# ...                                                 ...
# 5169  Awal nya sih bagus aja,tapi lama2 maksa premiu...
# 5170  Saya kasih bintang 4 aja kalau tau hasilnya ba...
# 5171  pelit lu ngeliat tag orang aja harus premium dulu
# 5172                                              Bagus
# 5173  ditunggu sebulan lebih kagak baljk2 anjg premi...
#
#                                       content_remove_at  \
# 0     nomor saya gbsa verifikasi udh puluhan kali di...
# 1     Some number can refuse to be seen on their tag...
# 2               Kembalikan getcontact seperti dulu woyy
# 3                                                  baik
# 4         Dulu gratis skrg berbayar.. Uninstall aja lah
# ...                                                 ...
# 5169  Awal nya sih bagus aja,tapi lama2 maksa premiu...
# 5170  Saya kasih bintang 4 aja kalau tau hasilnya ba...
# 5171  pelit lu ngeliat tag orang aja harus premium dulu
# 5172                                              Bagus
# 5173  ditunggu sebulan lebih kagak baljk2 anjg premi...
#
#                                     content_remove_link
# 0     nomor saya gbsa verifikasi udh puluhan kali di...
# 1     Some number can refuse to be seen on their tag...
# 2               Kembalikan getcontact seperti dulu woyy
# 3                                                  baik
# 4         Dulu gratis skrg berbayar.. Uninstall aja lah
# ...                                                 ...
# 5169  Awal nya sih bagus aja,tapi lama2 maksa premiu...
# 5170  Saya kasih bintang 4 aja kalau tau hasilnya ba...
# 5171  pelit lu ngeliat tag orang aja harus premium dulu
# 5172                                              Bagus
# 5173  ditunggu sebulan lebih kagak baljk2 anjg premi...
#
# [5174 rows x 3 columns]

# %%
import re
df['content_remove_simbol'] = df['content_remove_link'].apply(lambda x: re.sub(r'[^\w\s.,!?]', '', x))
df
# Out:
#                                                 content  \
# 0     nomor saya gbsa verifikasi udh puluhan kali di...
# 1     Some number can refuse to be seen on their tag...
# 2               Kembalikan getcontact seperti dulu woyy
# 3                                                  baik
# 4         Dulu gratis skrg berbayar.. Uninstall aja lah
# ...                                                 ...
# 5169  Awal nya sih bagus aja,tapi lama2 maksa premiu...
# 5170  Saya kasih bintang 4 aja kalau tau hasilnya ba...
# 5171  pelit lu ngeliat tag orang aja harus premium dulu
# 5172                                              Bagus
# 5173  ditunggu sebulan lebih kagak baljk2 anjg premi...
#
#                                       content_remove_at  \
# 0     nomor saya gbsa verifikasi udh puluhan kali di...
# 1     Some number can refuse to be seen on their tag...
# 2               Kembalikan getcontact seperti dulu woyy
# 3                                                  baik
# 4         Dulu gratis skrg berbayar.. Uninstall aja lah
# ...                                                 ...
# 5169  Awal nya sih bagus aja,tapi lama2 maksa premiu...
# 5170  Saya kasih bintang 4 aja kalau tau hasilnya ba...
# 5171  pelit lu ngeliat tag orang aja harus premium dulu
# 5172                                              Bagus
# 5173  ditunggu sebulan lebih kagak baljk2 anjg premi...
#
#                                     content_remove_link  \
# 0     nomor saya gbsa verifikasi udh puluhan kali di...
# 1     Some number can refuse to be seen on their tag...
# 2               Kembalikan getcontact seperti dulu woyy
# 3                                                  baik
# 4         Dulu gratis skrg berbayar.. Uninstall aja lah
# ...                                                 ...
# 5169  Awal nya sih bagus aja,tapi lama2 maksa premiu...
# 5170  Saya kasih bintang 4 aja kalau tau hasilnya ba...
# 5171  pelit lu ngeliat tag orang aja harus premium dulu
# 5172                                              Bagus
# 5173  ditunggu sebulan lebih kagak baljk2 anjg premi...
#
#                                   content_remove_simbol
# 0     nomor saya gbsa verifikasi udh puluhan kali di...
# 1     Some number can refuse to be seen on their tag...
# 2               Kembalikan getcontact seperti dulu woyy
# 3                                                  baik
# 4         Dulu gratis skrg berbayar.. Uninstall aja lah
# ...                                                 ...
# 5169  Awal nya sih bagus aja,tapi lama2 maksa premiu...
# 5170  Saya kasih bintang 4 aja kalau tau hasilnya ba...
# 5171  pelit lu ngeliat tag orang aja harus premium dulu
# 5172                                              Bagus
# 5173  ditunggu sebulan lebih kagak baljk2 anjg premi...
#
# [5174 rows x 4 columns]

# %%
# Menghapus data angka dari kolom 'content_remove_simbol' dan menyimpannya ke kolom 'content_remove_angka'
df['content_remove_angka'] = df['content_remove_simbol'].apply(lambda x: re.sub(r'\d+', '', x))

df
# Out:
#                                                 content  \
# 0     nomor saya gbsa verifikasi udh puluhan kali di...
# 1     Some number can refuse to be seen on their tag...
# 2               Kembalikan getcontact seperti dulu woyy
# 3                                                  baik
# 4         Dulu gratis skrg berbayar.. Uninstall aja lah
# ...                                                 ...
# 5169  Awal nya sih bagus aja,tapi lama2 maksa premiu...
# 5170  Saya kasih bintang 4 aja kalau tau hasilnya ba...
# 5171  pelit lu ngeliat tag orang aja harus premium dulu
# 5172                                              Bagus
# 5173  ditunggu sebulan lebih kagak baljk2 anjg premi...
#
#                                       content_remove_at  \
# 0     nomor saya gbsa verifikasi udh puluhan kali di...
# 1     Some number can refuse to be seen on their tag...
# 2               Kembalikan getcontact seperti dulu woyy
# 3                                                  baik
# 4         Dulu gratis skrg berbayar.. Uninstall aja lah
# ...                                                 ...
# 5169  Awal nya sih bagus aja,tapi lama2 maksa premiu...
# 5170  Saya kasih bintang 4 aja kalau tau hasilnya ba...
# 5171  pelit lu ngeliat tag orang aja harus premium dulu
# 5172                                              Bagus
# 5173  ditunggu sebulan lebih kagak baljk2 anjg premi...
#
#                                     content_remove_link  \
# 0     nomor saya gbsa verifikasi udh puluhan kali di...
# 1     Some number can refuse to be seen on their tag...
# 2               Kembalikan getcontact seperti dulu woyy
# 3                                                  baik
# 4         Dulu gratis skrg berbayar.. Uninstall aja lah
# ...                                                 ...
# 5169  Awal nya sih bagus aja,tapi lama2 maksa premiu...
# 5170  Saya kasih bintang 4 aja kalau tau hasilnya ba...
# 5171  pelit lu ngeliat tag orang aja harus premium dulu
# 5172                                              Bagus
# 5173  ditunggu sebulan lebih kagak baljk2 anjg premi...
#
#                                   content_remove_simbol  \
# 0     nomor saya gbsa verifikasi udh puluhan kali di...
# 1     Some number can refuse to be seen on their tag...
# 2               Kembalikan getcontact seperti dulu woyy
# 3                                                  baik
# 4         Dulu gratis skrg berbayar.. Uninstall aja lah
# ...                                                 ...
# 5169  Awal nya sih bagus aja,tapi lama2 maksa premiu...
# 5170  Saya kasih bintang 4 aja kalau tau hasilnya ba...
# 5171  pelit lu ngeliat tag orang aja harus premium dulu
# 5172                                              Bagus
# 5173  ditunggu sebulan lebih kagak baljk2 anjg premi...
#
#                                    content_remove_angka
# 0     nomor saya gbsa verifikasi udh puluhan kali di...
# 1     Some number can refuse to be seen on their tag...
# 2               Kembalikan getcontact seperti dulu woyy
# 3                                                  baik
# 4         Dulu gratis skrg berbayar.. Uninstall aja lah
# ...                                                 ...
# 5169  Awal nya sih bagus aja,tapi lama maksa premium...
# 5170  Saya kasih bintang  aja kalau tau hasilnya bar...
# 5171  pelit lu ngeliat tag orang aja harus premium dulu
# 5172                                              Bagus
# 5173  ditunggu sebulan lebih kagak baljk anjg premiu...
#
# [5174 rows x 5 columns]

# %%
def remove_extra_spaces(text):
    return re.sub(r'\s+', ' ', text)

df['content_remove_spaces'] = df['content_remove_angka'].apply(remove_extra_spaces)
df
# Out:
#                                                 content  \
# 0     nomor saya gbsa verifikasi udh puluhan kali di...
# 1     Some number can refuse to be seen on their tag...
# 2               Kembalikan getcontact seperti dulu woyy
# 3                                                  baik
# 4         Dulu gratis skrg berbayar.. Uninstall aja lah
# ...                                                 ...
# 5169  Awal nya sih bagus aja,tapi lama2 maksa premiu...
# 5170  Saya kasih bintang 4 aja kalau tau hasilnya ba...
# 5171  pelit lu ngeliat tag orang aja harus premium dulu
# 5172                                              Bagus
# 5173  ditunggu sebulan lebih kagak baljk2 anjg premi...
#
#                                       content_remove_at  \
# 0     nomor saya gbsa verifikasi udh puluhan kali di...
# 1     Some number can refuse to be seen on their tag...
# 2               Kembalikan getcontact seperti dulu woyy
# 3                                                  baik
# 4         Dulu gratis skrg berbayar.. Uninstall aja lah
# ...                                                 ...
# 5169  Awal nya sih bagus aja,tapi lama2 maksa premiu...
# 5170  Saya kasih bintang 4 aja kalau tau hasilnya ba...
# 5171  pelit lu ngeliat tag orang aja harus premium dulu
# 5172                                              Bagus
# 5173  ditunggu sebulan lebih kagak baljk2 anjg premi...
#
#                                     content_remove_link  \
# 0     nomor saya gbsa verifikasi udh puluhan kali di...
# 1     Some number can refuse to be seen on their tag...
# 2               Kembalikan getcontact seperti dulu woyy
# 3                                                  baik
# 4         Dulu gratis skrg berbayar.. Uninstall aja lah
# ...                                                 ...
# 5169  Awal nya sih bagus aja,tapi lama2 maksa premiu...
# 5170  Saya kasih bintang 4 aja kalau tau hasilnya ba...
# 5171  pelit lu ngeliat tag orang aja harus premium dulu
# 5172                                              Bagus
# 5173  ditunggu sebulan lebih kagak baljk2 anjg premi...
#
#                                   content_remove_simbol  \
# 0     nomor saya gbsa verifikasi udh puluhan kali di...
# 1     Some number can refuse to be seen on their tag...
# 2               Kembalikan getcontact seperti dulu woyy
# 3                                                  baik
# 4         Dulu gratis skrg berbayar.. Uninstall aja lah
# ...                                                 ...
# 5169  Awal nya sih bagus aja,tapi lama2 maksa premiu...
# 5170  Saya kasih bintang 4 aja kalau tau hasilnya ba...
# 5171  pelit lu ngeliat tag orang aja harus premium dulu
# 5172                                              Bagus
# 5173  ditunggu sebulan lebih kagak baljk2 anjg premi...
#
#                                    content_remove_angka  \
# 0     nomor saya gbsa verifikasi udh puluhan kali di...
# 1     Some number can refuse to be seen on their tag...
# 2               Kembalikan getcontact seperti dulu woyy
# 3                                                  baik
# 4         Dulu gratis skrg berbayar.. Uninstall aja lah
# ...                                                 ...
# 5169  Awal nya sih bagus aja,tapi lama maksa premium...
# 5170  Saya kasih bintang  aja kalau tau hasilnya bar...
# 5171  pelit lu ngeliat tag orang aja harus premium dulu
# 5172                                              Bagus
# 5173  ditunggu sebulan lebih kagak baljk anjg premiu...
#
#                                   content_remove_spaces
# 0     nomor saya gbsa verifikasi udh puluhan kali di...
# 1     Some number can refuse to be seen on their tag...
# 2               Kembalikan getcontact seperti dulu woyy
# 3                                                  baik
# 4         Dulu gratis skrg berbayar.. Uninstall aja lah
# ...                                                 ...
# 5169  Awal nya sih bagus aja,tapi lama maksa premium...
# 5170  Saya kasih bintang aja kalau tau hasilnya baru...
# 5171  pelit lu ngeliat tag orang aja harus premium dulu
# 5172                                              Bagus
# 5173  ditunggu sebulan lebih kagak baljk anjg premiu...
#
# [5174 rows x 6 columns]

# %%
print(df.duplicated().sum())  # Menampilkan jumlah data duplikat
# Out:
# 790

# %%
# Mengatasi duplikasi
df = df.drop_duplicates()

# %%
print(df.duplicated().sum())  # Menampilkan jumlah data duplikat
# Out:
# 0

# %%
# Validasi data
df  # Memeriksa data setelah tahap pembersihan
# Out:
#                                                 content  \
# 0     nomor saya gbsa verifikasi udh puluhan kali di...
# 1     Some number can refuse to be seen on their tag...
# 2               Kembalikan getcontact seperti dulu woyy
# 3                                                  baik
# 4         Dulu gratis skrg berbayar.. Uninstall aja lah
# ...                                                 ...
# 5168  Aku udah mencoba masuk beberapa kali lebih len...
# 5169  Awal nya sih bagus aja,tapi lama2 maksa premiu...
# 5170  Saya kasih bintang 4 aja kalau tau hasilnya ba...
# 5171  pelit lu ngeliat tag orang aja harus premium dulu
# 5173  ditunggu sebulan lebih kagak baljk2 anjg premi...
#
#                                       content_remove_at  \
# 0     nomor saya gbsa verifikasi udh puluhan kali di...
# 1     Some number can refuse to be seen on their tag...
# 2               Kembalikan getcontact seperti dulu woyy
# 3                                                  baik
# 4         Dulu gratis skrg berbayar.. Uninstall aja lah
# ...                                                 ...
# 5168  Aku udah mencoba masuk beberapa kali lebih len...
# 5169  Awal nya sih bagus aja,tapi lama2 maksa premiu...
# 5170  Saya kasih bintang 4 aja kalau tau hasilnya ba...
# 5171  pelit lu ngeliat tag orang aja harus premium dulu
# 5173  ditunggu sebulan lebih kagak baljk2 anjg premi...
#
#                                     content_remove_link  \
# 0     nomor saya gbsa verifikasi udh puluhan kali di...
# 1     Some number can refuse to be seen on their tag...
# 2               Kembalikan getcontact seperti dulu woyy
# 3                                                  baik
# 4         Dulu gratis skrg berbayar.. Uninstall aja lah
# ...                                                 ...
# 5168  Aku udah mencoba masuk beberapa kali lebih len...
# 5169  Awal nya sih bagus aja,tapi lama2 maksa premiu...
# 5170  Saya kasih bintang 4 aja kalau tau hasilnya ba...
# 5171  pelit lu ngeliat tag orang aja harus premium dulu
# 5173  ditunggu sebulan lebih kagak baljk2 anjg premi...
#
#                                   content_remove_simbol  \
# 0     nomor saya gbsa verifikasi udh puluhan kali di...
# 1     Some number can refuse to be seen on their tag...
# 2               Kembalikan getcontact seperti dulu woyy
# 3                                                  baik
# 4         Dulu gratis skrg berbayar.. Uninstall aja lah
# ...                                                 ...
# 5168  Aku udah mencoba masuk beberapa kali lebih len...
# 5169  Awal nya sih bagus aja,tapi lama2 maksa premiu...
# 5170  Saya kasih bintang 4 aja kalau tau hasilnya ba...
# 5171  pelit lu ngeliat tag orang aja harus premium dulu
# 5173  ditunggu sebulan lebih kagak baljk2 anjg premi...
#
#                                    content_remove_angka  \
# 0     nomor saya gbsa verifikasi udh puluhan kali di...
# 1     Some number can refuse to be seen on their tag...
# 2               Kembalikan getcontact seperti dulu woyy
# 3                                                  baik
# 4         Dulu gratis skrg berbayar.. Uninstall aja lah
# ...                                                 ...
# 5168  Aku udah mencoba masuk beberapa kali lebih len...
# 5169  Awal nya sih bagus aja,tapi lama maksa premium...
# 5170  Saya kasih bintang  aja kalau tau hasilnya bar...
# 5171  pelit lu ngeliat tag orang aja harus premium dulu
# 5173  ditunggu sebulan lebih kagak baljk anjg premiu...
#
#                                   content_remove_spaces
# 0     nomor saya gbsa verifikasi udh puluhan kali di...
# 1     Some number can refuse to be seen on their tag...
# 2               Kembalikan getcontact seperti dulu woyy
# 3                                                  baik
# 4         Dulu gratis skrg berbayar.. Uninstall aja lah
# ...                                                 ...
# 5168  Aku udah mencoba masuk beberapa kali lebih len...
# 5169  Awal nya sih bagus aja,tapi lama maksa premium...
# 5170  Saya kasih bintang aja kalau tau hasilnya baru...
# 5171  pelit lu ngeliat tag orang aja harus premium dulu
# 5173  ditunggu sebulan lebih kagak baljk anjg premiu...
#
# [4384 rows x 6 columns]

# %%
# Ambil hanya kolom 'content_remove_spaces'
df = df[['content_remove_spaces']]
df
# Out:
#                                   content_remove_spaces
# 0     nomor saya gbsa verifikasi udh puluhan kali di...
# 1     Some number can refuse to be seen on their tag...
# 2               Kembalikan getcontact seperti dulu woyy
# 3                                                  baik
# 4         Dulu gratis skrg berbayar.. Uninstall aja lah
# ...                                                 ...
# 5168  Aku udah mencoba masuk beberapa kali lebih len...
# 5169  Awal nya sih bagus aja,tapi lama maksa premium...
# 5170  Saya kasih bintang aja kalau tau hasilnya baru...
# 5171  pelit lu ngeliat tag orang aja harus premium dulu
# 5173  ditunggu sebulan lebih kagak baljk anjg premiu...
#
# [4384 rows x 1 columns]

# %%
# Mengganti nama kolom untuk konten yang telah dibersihkan
df = df.rename(columns={'content_remove_spaces': 'content'})

# %%
df
# Out:
#                                                 content
# 0     nomor saya gbsa verifikasi udh puluhan kali di...
# 1     Some number can refuse to be seen on their tag...
# 2               Kembalikan getcontact seperti dulu woyy
# 3                                                  baik
# 4         Dulu gratis skrg berbayar.. Uninstall aja lah
# ...                                                 ...
# 5168  Aku udah mencoba masuk beberapa kali lebih len...
# 5169  Awal nya sih bagus aja,tapi lama maksa premium...
# 5170  Saya kasih bintang aja kalau tau hasilnya baru...
# 5171  pelit lu ngeliat tag orang aja harus premium dulu
# 5173  ditunggu sebulan lebih kagak baljk anjg premiu...
#
# [4384 rows x 1 columns]

# %%
# Memeriksa total data setelah menghapus tanda baca dan spasi tambahan
total_data = df.shape[0]
print("Total data setelah penghapusan tanda baca dan spasi tambahan:", total_data)
# Out:
# Total data setelah penghapusan tanda baca dan spasi tambahan: 4384

# %%
# Menyimpan data yang telah dibersihkan
df.to_csv('/content/drive/MyDrive/Portfolio/Sentiment Analysis User Reviews App GetContact/CleanedGetContact.csv', index=False)
